# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniomuso/speech2face/blob/master/Decoder_with_warping_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ! rm -r Face_Feature

# ! ls -l Face_Feature/Faces | wc -l
! pip install face_recognition
! pip3 install tensorflow-gpu==1.15
# Out:
# Collecting face_recognition
#   Downloading https://files.pythonhosted.org/packages/1e/95/f6c9330f54ab07bfa032bf3715c12455a381083125d8880c43cbe76bb3d0/face_recognition-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.0.0)
# Collecting face-recognition-models>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/cf/3b/4fd8c534f6c0d1b80ce0973d01331525538045084c73c153ee6df20224cf/face_recognition_models-0.3.0.tar.gz (100.1MB)
#      |████████████████████████████████| 100.2MB 113kB/s
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from face_recognition) (1.18.5)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.1.2)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=52c69171f43d1f913c8c345e0a8968705cf4bea35b81e20e457ecd9f1e8d4036
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0
# Collecting tensorflow-gpu==1.15
#   Downloading https://files.pythonhosted.org/packages/a5/ad/933140e74973fb917a194ab814785e7c23680ca5dee6d663a509fe9579b6/tensorflow_gpu-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (411.5MB)
#      |████████████████████████████████| 411.5MB 42kB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.35.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.15.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 54.2MB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 47.4MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.1.2)
# Collecting keras-applications>=1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 8.4MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.18.5)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (3.12.4)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (0.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (3.2.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (50.3.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=4be2c2ed3b3191a9312ad202b1f89cceef2ceffd1373b28842089bef0b6a0e5e
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.3.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorflow-estimator<2.4.0,>=2.3.0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, keras-applications, gast, tensorflow-gpu
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.0

# %%
! cp /content/drive/My\ Drive/Speech2Face/face_features_40_per_actor.zip .
! unzip face_features_40_per_actor.zip
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: Face_Feature/Faces/Chris_Martin_22002.jpg
#   inflating: Face_Feature/Faces/Luke_Evans_49661.jpg
#   inflating: Face_Feature/Faces/Tamara_Taylor_15481.jpg
#   inflating: Face_Feature/Faces/Vanessa_Hudgens_48012.jpg
#   inflating: Face_Feature/Faces/Clive_Owen_38763.jpg
#   inflating: Face_Feature/Faces/Yvette_Nicole_Brown_46045.jpg
#   inflating: Face_Feature/Faces/Pete_Wentz_13250.jpg
#   inflating: Face_Feature/Faces/Dana_Delany_25207.jpg
#   inflating: Face_Feature/Faces/Cilla_Black_23567.jpg
#   inflating: Face_Feature/Faces/Beth_Grant_17569.jpg
#   inflating: Face_Feature/Faces/Janel_Parrish_38029.jpg
#   inflating: Face_Feature/Faces/Karoline_Herfurth_34700.jpg
#   inflating: Face_Feature/Faces/Ron_Jeremy_5759.jpg
#   inflating: Face_Feature/Faces/Sharni_Vinson_32805.jpg
#   inflating: Face_Feature/Faces/Finola_Hughes_36948.jpg
#   inflating: Face_Feature/Faces/Johnny_Galecki_5820.jpg
#   inflating: Face_Feature/Faces/Nina_Hoss_35699.jpg
#   inflating: Face_Feature/Faces/Andrea_Riseborough_2263.jpg
#   inflating: Face_Feature/Faces/Laura_Carmichael_40948.jpg
#   inflating: Face_Feature/Faces/Teala_Dunn_20814.jpg
#   inflating: Face_Feature/Faces/Mya_34901.jpg
#   inflating: Face_Feature/Faces/Chelsea_Handler_34325.jpg
#   inflating: Face_Feature/Faces/Rebel_Wilson_26546.jpg
#   inflating: Face_Feature/Faces/Kate_Mansi_10020.jpg
#   inflating: Face_Feature/Faces/Fawad_Khan_47792.jpg
#   inflating: Face_Feature/Faces/Sharon_Gless_32778.jpg
#   inflating: Face_Feature/Faces/Indira_Varma_39785.jpg
#   inflating: Face_Feature/Faces/Shonda_Rhimes_48869.jpg
#   inflating: Face_Feature/Faces/John_Abraham_31386.jpg
#   inflating: Face_Feature/Faces/Fanny_Ardant_39387.jpg
#   inflating: Face_Feature/Faces/Joel_Kinnaman_29223.jpg
#   inflating: Face_Feature/Faces/David_Mamet_3613.jpg
#   inflating: Face_Feature/Faces/Nelly_Furtado_2683.jpg
#   inflating: Face_Feature/Faces/Julian_Sands_42920.jpg
#   inflating: Face_Feature/Faces/Diane_Kruger_24577.jpg
#   inflating: Face_Feature/Faces/Claudia_Black_19802.jpg
#   inflating: Face_Feature/Faces/Kat_Dennings_46171.jpg
#   inflating: Face_Feature/Faces/Tom_Ford_4432.jpg
#   inflating: Face_Feature/Faces/Henry_Cavill_39344.jpg
#   inflating: Face_Feature/Faces/Alison_Arngrim_44099.jpg
#   inflating: Face_Feature/Faces/Scott_Speedman_31266.jpg
#   inflating: Face_Feature/Faces/Rade_Serbedzija_17089.jpg
#   inflating: Face_Feature/Faces/Andrea_Riseborough_2278.jpg
#   inflating: Face_Feature/Faces/Abigail_Spencer_36756.jpg
#   inflating: Face_Feature/Faces/Sonja_Sohn_29040.jpg
#   inflating: Face_Feature/Faces/Michael_Cudlitz_27361.jpg
#   inflating: Face_Feature/Faces/Jamie_Foxx_29721.jpg
#   inflating: Face_Feature/Faces/Meghan_Trainor_17920.jpg
#   inflating: Face_Feature/Faces/Jeff_Garlin_6294.jpg
#   inflating: Face_Feature/Faces/Oona_Chaplin_6455.jpg
#   inflating: Face_Feature/Faces/Moon_Bloodgood_6057.jpg
#   inflating: Face_Feature/Faces/Josh_Brolin_25991.jpg
#   inflating: Face_Feature/Faces/Natalie_Dormer_5488.jpg
#   inflating: Face_Feature/Faces/Reece_Ritchie_35130.jpg
#   inflating: Face_Feature/Faces/Preity_Zinta_32234.jpg
#   inflating: Face_Feature/Faces/Greta_Gerwig_35911.jpg
#   inflating: Face_Feature/Faces/Sarah_Bolger_31859.jpg
#   inflating: Face_Feature/Faces/Kimberly_Elise_11461.jpg
#   inflating: Face_Feature/Faces/Marcia_Gay_Harden_20238.jpg
#   inflating: Face_Feature/Faces/Amaury_Nolasco_37546.jpg
#   inflating: Face_Feature/Faces/Elaine_Cassidy_3721.jpg
#   inflating: Face_Feature/Faces/Michelle_Stafford_19522.jpg
#   inflating: Face_Feature/Faces/Katy_Perry_48090.jpg
#   inflating: Face_Feature/Faces/Josh_Radnor_13673.jpg
#   inflating: Face_Feature/Faces/Marc_Forster_27628.jpg
#   inflating: Face_Feature/Faces/Matthew_Modine_38147.jpg
#   inflating: Face_Feature/Faces/Vanessa_Marcil_34646.jpg
#   inflating: Face_Feature/Faces/Casey_Affleck_9732.jpg
#   inflating: Face_Feature/Faces/Ansel_Elgort_44904.jpg
#   inflating: Face_Feature/Faces/Peter_Coyote_27814.jpg
#   inflating: Face_Feature/Faces/John_Oliver_22182.jpg
#   inflating: Face_Feature/Faces/Janina_Gavankar_37362.jpg
#   inflating: Face_Feature/Faces/Ryan_Kwanten_41474.jpg
#   inflating: Face_Feature/Faces/Chris_Pine_18301.jpg
#   inflating: Face_Feature/Faces/Alexandra_Roach_34170.jpg
#   inflating: Face_Feature/Faces/Caterina_Murino_28490.jpg
#   inflating: Face_Feature/Faces/Julian_Sands_42933.jpg
#   inflating: Face_Feature/Faces/Will_Poulter_33649.jpg
#   inflating: Face_Feature/Faces/John_Hurt_25038.jpg
#   inflating: Face_Feature/Faces/Keegan_Connor_Tracy_38367.jpg
#   inflating: Face_Feature/Faces/Kenny_Rogers_42549.jpg
#   inflating: Face_Feature/Faces/John_Lloyd_Young_18744.jpg
#   inflating: Face_Feature/Faces/Jim_Jefferies_10991.jpg
#   inflating: Face_Feature/Faces/Jon_Seda_44507.jpg
#   inflating: Face_Feature/Faces/Troye_Sivan_24781.jpg
#   inflating: Face_Feature/Faces/Shonda_Rhimes_48862.jpg
#   inflating: Face_Feature/Faces/Julia_Roberts_34141.jpg
#   inflating: Face_Feature/Faces/Robert_Pattinson_10095.jpg
#   inflating: Face_Feature/Faces/Abbie_Cornish_39958.jpg
#   inflating: Face_Feature/Faces/Adam_Brody_6606.jpg
#   inflating: Face_Feature/Faces/Lindsey_Morgan_27327.jpg
#   inflating: Face_Feature/Faces/Tony_Curran_32292.jpg
#   inflating: Face_Feature/Faces/Rue_McClanahan_29681.jpg
#   inflating: Face_Feature/Faces/Billie_Joe_Armstrong_38389.jpg
#   inflating: Face_Feature/Faces/Kelly_Brook_28887.jpg
#   inflating: Face_Feature/Faces/Jeremy_Piven_17450.jpg
#   inflating: Face_Feature/Faces/Olivia_Munn_34275.jpg
#   inflating: Face_Feature/Faces/Scott_Porter_17997.jpg
#   inflating: Face_Feature/Faces/Debi_Mazar_45063.jpg
#   inflating: Face_Feature/Faces/Rose_McIver_18850.jpg
#   inflating: Face_Feature/Faces/Maria_de_Medeiros_3546.jpg
#   inflating: Face_Feature/Faces/Tahmoh_Penikett_33142.jpg
#   inflating: Face_Feature/Faces/Blake_Michael_13311.jpg
#   inflating: Face_Feature/Faces/Phyllis_Diller_2340.jpg
#   inflating: Face_Feature/Faces/Keri_Hilson_9655.jpg
#   inflating: Face_Feature/Faces/Amy_Poehler_13211.jpg
#   inflating: Face_Feature/Faces/Erin_Andrews_30636.jpg
#   inflating: Face_Feature/Faces/Seth_Green_11505.jpg
#   inflating: Face_Feature/Faces/Nazanin_Boniadi_30423.jpg
#   inflating: Face_Feature/Faces/Nancy_Cartwright_24467.jpg
#   inflating: Face_Feature/Faces/Joseph_Gordon-Levitt_39076.jpg
#   inflating: Face_Feature/Faces/Alba_Rohrwacher_25326.jpg
#   inflating: Face_Feature/Faces/Rachel_McAdams_33284.jpg
#   inflating: Face_Feature/Faces/Jennifer_Beals_36304.jpg
#   inflating: Face_Feature/Faces/Hugh_Laurie_5946.jpg
#   inflating: Face_Feature/Faces/Sean_Patrick_Flanery_35247.jpg
#   inflating: Face_Feature/Faces/James_Lafferty_5148.jpg
#   inflating: Face_Feature/Faces/Eugene_Levy_36783.jpg
#   inflating: Face_Feature/Faces/Kathryn_McCormick_2179.jpg
#   inflating: Face_Feature/Faces/Grant_Bowler_17289.jpg
#   inflating: Face_Feature/Faces/Suzanne_Pleshette_18801.jpg
#   inflating: Face_Feature/Faces/Seth_Rogen_17600.jpg
#   inflating: Face_Feature/Faces/Ron_Jeremy_5725.jpg
#   inflating: Face_Feature/Faces/Lindsay_Duncan_8036.jpg
#   inflating: Face_Feature/Faces/Kate_Flannery_9096.jpg
#   inflating: Face_Feature/Faces/Wentworth_Miller_39159.jpg
#   inflating: Face_Feature/Faces/Timothy_Spall_32891.jpg
#   inflating: Face_Feature/Faces/Kaya_Scodelario_27699.jpg
#   inflating: Face_Feature/Faces/Katherine_Jenkins_24986.jpg
#   inflating: Face_Feature/Faces/Sammi_Hanratty_40888.jpg
#   inflating: Face_Feature/Faces/Josh_Duhamel_24596.jpg
#   inflating: Face_Feature/Faces/Toby_Jones_25675.jpg
#   inflating: Face_Feature/Faces/Natalie_Zea_31788.jpg
#   inflating: Face_Feature/Faces/Ben_Stiller_48224.jpg
#   inflating: Face_Feature/Faces/Josh_Gad_13845.jpg
#   inflating: Face_Feature/Faces/Paul_Sorvino_20204.jpg
#   inflating: Face_Feature/Faces/Lucy_Punch_34521.jpg
#   inflating: Face_Feature/Faces/Fiona_Shaw_2539.jpg
#   inflating: Face_Feature/Faces/Moritz_Bleibtreu_9151.jpg
#   inflating: Face_Feature/Faces/Sam_Palladio_1085.jpg
#   inflating: Face_Feature/Faces/Janet_Jackson_5782.jpg
#   inflating: Face_Feature/Faces/Shane_West_43090.jpg
#   inflating: Face_Feature/Faces/William_Baldwin_1964.jpg
#   inflating: Face_Feature/Faces/David_Morrissey_23398.jpg
#   inflating: Face_Feature/Faces/Jenifer_Lewis_41708.jpg
#   inflating: Face_Feature/Faces/Melissa_Rycroft_29609.jpg
#   inflating: Face_Feature/Faces/Tony_Curran_32275.jpg
#   inflating: Face_Feature/Faces/Theo_Rossi_9413.jpg
#   inflating: Face_Feature/Faces/Ruth_Wilson_23590.jpg
#   inflating: Face_Feature/Faces/Vanessa_Hudgens_48010.jpg
#   inflating: Face_Feature/Faces/Hill_Harper_7545.jpg
#   inflating: Face_Feature/Faces/Jason_Mantzoukas_38494.jpg
#   inflating: Face_Feature/Faces/Patrick_Dempsey_49515.jpg
#   inflating: Face_Feature/Faces/Kate_Mansi_9994.jpg
#   inflating: Face_Feature/Faces/Cote_de_Pablo_27865.jpg
#   inflating: Face_Feature/Faces/Pierfrancesco_Favino_2159.jpg
#   inflating: Face_Feature/Faces/Golshifteh_Farahani_26623.jpg
#   inflating: Face_Feature/Faces/Olivia_Colman_20584.jpg
#   inflating: Face_Feature/Faces/Carrie_Ann_Inaba_4510.jpg
#   inflating: Face_Feature/Faces/Rainn_Wilson_8355.jpg
#   inflating: Face_Feature/Faces/Cheryl_Ladd_32319.jpg
#   inflating: Face_Feature/Faces/Todd_Lasance_48963.jpg
#   inflating: Face_Feature/Faces/Naseeruddin_Shah_26837.jpg
#   inflating: Face_Feature/Faces/Tracy_Morgan_27903.jpg
#   inflating: Face_Feature/Faces/Jeremy_Piven_17417.jpg
#   inflating: Face_Feature/Faces/Sally_Hawkins_30752.jpg
#   inflating: Face_Feature/Faces/Kyle_Richards_48122.jpg
#   inflating: Face_Feature/Faces/Robbie_Amell_9073.jpg
#   inflating: Face_Feature/Faces/Michael_C._Hall_41780.jpg
#   inflating: Face_Feature/Faces/Rob_Dyrdek_29835.jpg
#   inflating: Face_Feature/Faces/Timothy_Spall_32877.jpg
#   inflating: Face_Feature/Faces/Chelsea_Handler_34331.jpg
#   inflating: Face_Feature/Faces/Mira_Furlan_37215.jpg
#   inflating: Face_Feature/Faces/Cliff_Curtis_18624.jpg
#   inflating: Face_Feature/Faces/Melissa_Rycroft_29602.jpg
#   inflating: Face_Feature/Faces/Lucie_Arnaz_13711.jpg
#   inflating: Face_Feature/Faces/Rachel_McAdams_33289.jpg
#   inflating: Face_Feature/Faces/Sendhil_Ramamurthy_19625.jpg
#   inflating: Face_Feature/Faces/Laura_Benanti_23093.jpg
#   inflating: Face_Feature/Faces/Edgar_Wright_16607.jpg
#   inflating: Face_Feature/Faces/Elisabeth_Moss_48715.jpg
#   inflating: Face_Feature/Faces/Charlie_Day_14828.jpg
#   inflating: Face_Feature/Faces/Bruce_Boxleitner_33969.jpg
#   inflating: Face_Feature/Faces/Steve_Jobs_24079.jpg
#   inflating: Face_Feature/Faces/Audrina_Patridge_11630.jpg
#   inflating: Face_Feature/Faces/Scott_Speedman_31265.jpg
#   inflating: Face_Feature/Faces/Joel_Kinnaman_29217.jpg
#   inflating: Face_Feature/Faces/Kendra_Wilkinson_48636.jpg
#   inflating: Face_Feature/Faces/Eva_Longoria_19777.jpg
#   inflating: Face_Feature/Faces/Zoe_Saldana_23437.jpg
#   inflating: Face_Feature/Faces/Marisa_Miller_33566.jpg
#   inflating: Face_Feature/Faces/Anthony_Mackie_12408.jpg
#   inflating: Face_Feature/Faces/Tatiana_Maslany_34615.jpg
#   inflating: Face_Feature/Faces/Hye-kyo_Song_12331.jpg
#   inflating: Face_Feature/Faces/Taraji_P._Henson_29254.jpg
#   inflating: Face_Feature/Faces/Natalie_Dormer_5495.jpg
#   inflating: Face_Feature/Faces/Russell_Peters_14282.jpg
#   inflating: Face_Feature/Faces/Christina_Hendricks_4837.jpg
#   inflating: Face_Feature/Faces/Sharlto_Copley_2373.jpg
#   inflating: Face_Feature/Faces/Neil_deGrasse_Tyson_20539.jpg
#   inflating: Face_Feature/Faces/Tatyana_Ali_16855.jpg
#   inflating: Face_Feature/Faces/Jillian_Michaels_17098.jpg
#   inflating: Face_Feature/Faces/Corbin_Bleu_33632.jpg
#   inflating: Face_Feature/Faces/Lucy_Punch_34538.jpg
#   inflating: Face_Feature/Faces/Mischa_Barton_25647.jpg
#   inflating: Face_Feature/Faces/Brenda_Blethyn_31187.jpg
#   inflating: Face_Feature/Faces/Erik_Estrada_3678.jpg
#   inflating: Face_Feature/Faces/Alan_Tudyk_19252.jpg
#   inflating: Face_Feature/Faces/Richard_Kind_43208.jpg
#   inflating: Face_Feature/Faces/Ashley_Jensen_5982.jpg
#   inflating: Face_Feature/Faces/Sam_Heughan_42173.jpg
#   inflating: Face_Feature/Faces/Manish_Dayal_35294.jpg
#   inflating: Face_Feature/Faces/Tim_Burton_27148.jpg
#   inflating: Face_Feature/Faces/Kris_Jenner_3561.jpg
#   inflating: Face_Feature/Faces/Jana_Kramer_43929.jpg
#   inflating: Face_Feature/Faces/Jason_Mantzoukas_38474.jpg
#   inflating: Face_Feature/Faces/Anne_Hathaway_49590.jpg
#   inflating: Face_Feature/Faces/Stephen_Lang_7221.jpg
#   inflating: Face_Feature/Faces/Taryn_Manning_29407.jpg
#   inflating: Face_Feature/Faces/Caterina_Scorsone_34059.jpg
#   inflating: Face_Feature/Faces/Michael_Shannon_30553.jpg
#   inflating: Face_Feature/Faces/Aldis_Hodge_32746.jpg
#   inflating: Face_Feature/Faces/Hannah_Spearritt_12466.jpg
#   inflating: Face_Feature/Faces/Marie_Avgeropoulos_3900.jpg
#   inflating: Face_Feature/Faces/Mya_34882.jpg
#   inflating: Face_Feature/Faces/Jerry_Trainor_42258.jpg
#   inflating: Face_Feature/Faces/Theo_Rossi_9420.jpg
#   inflating: Face_Feature/Faces/Nelly_1170.jpg
#   inflating: Face_Feature/Faces/Bruno_Mars_36896.jpg
#   inflating: Face_Feature/Faces/Kayvan_Novak_8863.jpg
#   inflating: Face_Feature/Faces/Vanessa_Marcil_34662.jpg
#   inflating: Face_Feature/Faces/Diane_Kruger_24553.jpg
#   inflating: Face_Feature/Faces/Rade_Serbedzija_17068.jpg
#   inflating: Face_Feature/Faces/Chris_Colfer_39451.jpg
#   inflating: Face_Feature/Faces/Viggo_Mortensen_14904.jpg
#   inflating: Face_Feature/Faces/Hye-kyo_Song_12360.jpg
#   inflating: Face_Feature/Faces/Eric_Dane_11278.jpg
#   inflating: Face_Feature/Faces/Keegan_Connor_Tracy_38371.jpg
#   inflating: Face_Feature/Faces/Kathryn_Joosten_7757.jpg
#   inflating: Face_Feature/Faces/Geri_Halliwell_42028.jpg
#   inflating: Face_Feature/Faces/Patrick_Duffy_16563.jpg
#   inflating: Face_Feature/Faces/Patrick_Dempsey_49481.jpg
#   inflating: Face_Feature/Faces/Oscar_Isaac_38128.jpg
#   inflating: Face_Feature/Faces/Fred_Williamson_20652.jpg
#   inflating: Face_Feature/Faces/Chris_Hemsworth_8672.jpg
#   inflating: Face_Feature/Faces/Karan_Brar_29789.jpg
#   inflating: Face_Feature/Faces/Dustin_Milligan_43462.jpg
#   inflating: Face_Feature/Faces/Lorde_41773.jpg
#   inflating: Face_Feature/Faces/Sam_Waterston_25136.jpg
#   inflating: Face_Feature/Faces/Natalia_Tena_14750.jpg
#   inflating: Face_Feature/Faces/Russell_Tovey_10034.jpg
#   inflating: Face_Feature/Faces/Denis_Leary_3120.jpg
#   inflating: Face_Feature/Faces/Eddie_Izzard_39604.jpg
#   inflating: Face_Feature/Faces/Woody_Harrelson_6899.jpg
#   inflating: Face_Feature/Faces/Dan_Aykroyd_15642.jpg
#   inflating: Face_Feature/Faces/Alan_Alda_23669.jpg
#   inflating: Face_Feature/Faces/Jasika_Nicole_25898.jpg
#   inflating: Face_Feature/Faces/Miley_Cyrus_1331.jpg
#   inflating: Face_Feature/Faces/Susan_Lucci_24231.jpg
#   inflating: Face_Feature/Faces/Hannah_Spearritt_12469.jpg
#   inflating: Face_Feature/Faces/Rene_Auberjonois_31613.jpg
#   inflating: Face_Feature/Faces/Edward_Asner_4399.jpg
#   inflating: Face_Feature/Faces/Maria_Grazia_Cucinotta_20997.jpg
#   inflating: Face_Feature/Faces/Rainn_Wilson_8350.jpg
#   inflating: Face_Feature/Faces/Vidya_Balan_15532.jpg
#   inflating: Face_Feature/Faces/Jack_Black_6402.jpg
#   inflating: Face_Feature/Faces/Zack_Snyder_23914.jpg
#   inflating: Face_Feature/Faces/Jeremy_Piven_17428.jpg
#   inflating: Face_Feature/Faces/Clive_Owen_38743.jpg
#   inflating: Face_Feature/Faces/Patrick_Dempsey_49498.jpg
#   inflating: Face_Feature/Faces/Nelly_Furtado_2718.jpg
#   inflating: Face_Feature/Faces/Lesley_Manville_37747.jpg
#   inflating: Face_Feature/Faces/Ken_Marino_31687.jpg
#   inflating: Face_Feature/Faces/J.K._Simmons_11701.jpg
#   inflating: Face_Feature/Faces/Ajay_Devgn_22321.jpg
#   inflating: Face_Feature/Faces/John_Lloyd_Young_18736.jpg
#   inflating: Face_Feature/Faces/Anthony_Rapp_13398.jpg
#   inflating: Face_Feature/Faces/Philip_Glenister_43252.jpg
#   inflating: Face_Feature/Faces/Dakota_Fanning_6327.jpg
#   inflating: Face_Feature/Faces/Mark_Sheppard_19452.jpg
#   inflating: Face_Feature/Faces/Melissa_Leo_7122.jpg
#   inflating: Face_Feature/Faces/Will_Forte_21099.jpg
#   inflating: Face_Feature/Faces/Thomas_Gibson_21728.jpg
#   inflating: Face_Feature/Faces/Patrick_Dempsey_49486.jpg
#   inflating: Face_Feature/Faces/Donal_Logue_9699.jpg
#   inflating: Face_Feature/Faces/Jennifer_Saunders_30386.jpg
#   inflating: Face_Feature/Faces/CCH_Pounder_4066.jpg
#   inflating: Face_Feature/Faces/Teri_Hatcher_12717.jpg
#   inflating: Face_Feature/Faces/Keeley_Hawes_11953.jpg
#   inflating: Face_Feature/Faces/Jai_Courtney_34408.jpg
#   inflating: Face_Feature/Faces/Sofia_Coppola_14661.jpg
#   inflating: Face_Feature/Faces/Aaron_Tveit_8931.jpg
#   inflating: Face_Feature/Faces/Kristen_Schaal_2056.jpg
#   inflating: Face_Feature/Faces/Patrick_Duffy_16543.jpg
#   inflating: Face_Feature/Faces/Olivia_Colman_20565.jpg
#   inflating: Face_Feature/Faces/Jordan_Gavaris_46588.jpg
#   inflating: Face_Feature/Faces/Danielle_Panabaker_27184.jpg
#   inflating: Face_Feature/Faces/Corbin_Bleu_33609.jpg
#   inflating: Face_Feature/Faces/Jessica_Lowndes_20973.jpg
#   inflating: Face_Feature/Faces/Paolo_Sorrentino_6956.jpg
#   inflating: Face_Feature/Faces/John_Carroll_Lynch_8114.jpg
#   inflating: Face_Feature/Faces/Mila_Kunis_7979.jpg
#   inflating: Face_Feature/Faces/Blake_Shelton_8205.jpg
#   inflating: Face_Feature/Faces/Gregg_Sulkin_24052.jpg
#   inflating: Face_Feature/Faces/Rik_Mayall_4225.jpg
#   inflating: Face_Feature/Faces/Jim_Caviezel_19118.jpg
#   inflating: Face_Feature/Faces/Claudia_Black_19807.jpg
#   inflating: Face_Feature/Faces/Arden_Cho_44968.jpg
#   inflating: Face_Feature/Faces/Lea_Thompson_10197.jpg
#   inflating: Face_Feature/Faces/Walton_Goggins_33367.jpg
#   inflating: Face_Feature/Faces/Paloma_Faith_33010.jpg
#   inflating: Face_Feature/Faces/Tamara_Tunie_49259.jpg
#   inflating: Face_Feature/Faces/Mary_Elizabeth_Winstead_44986.jpg
#   inflating: Face_Feature/Faces/Jen_Lilley_20493.jpg
#   inflating: Face_Feature/Faces/Janina_Gavankar_37366.jpg
#   inflating: Face_Feature/Faces/Ruth_Jones_28208.jpg
#   inflating: Face_Feature/Faces/Kenton_Duty_41188.jpg
#   inflating: Face_Feature/Faces/Ed_Westwick_38908.jpg
#   inflating: Face_Feature/Faces/Ron_Livingston_43758.jpg
#   inflating: Face_Feature/Faces/Lacey_Turner_40088.jpg
#   inflating: Face_Feature/Faces/Nelly_1190.jpg
#   inflating: Face_Feature/Faces/Eddie_Kaye_Thomas_40331.jpg
#   inflating: Face_Feature/Faces/Usher_Raymond_34476.jpg
#   inflating: Face_Feature/Faces/Karoline_Herfurth_34683.jpg
#   inflating: Face_Feature/Faces/Maria_Menounos_4567.jpg
#   inflating: Face_Feature/Faces/Walton_Goggins_33356.jpg
#   inflating: Face_Feature/Faces/Lotte_Verbeek_32143.jpg
#   inflating: Face_Feature/Faces/Eddie_McClintock_6147.jpg
#   inflating: Face_Feature/Faces/Taylor_Momsen_29911.jpg
#   inflating: Face_Feature/Faces/James_Lipton_37787.jpg
#   inflating: Face_Feature/Faces/Louis_C.K._30317.jpg
#   inflating: Face_Feature/Faces/Kim_Raver_1688.jpg
#   inflating: Face_Feature/Faces/Olivia_Colman_20558.jpg
#   inflating: Face_Feature/Faces/Nick_Kroll_39724.jpg
#   inflating: Face_Feature/Faces/Lucie_Arnaz_13720.jpg
#   inflating: Face_Feature/Faces/Sean_Maher_16302.jpg
#   inflating: Face_Feature/Faces/Aidan_Turner_9389.jpg
#   inflating: Face_Feature/Faces/Shannen_Doherty_21834.jpg
#   inflating: Face_Feature/Faces/Paddy_Considine_18265.jpg
#   inflating: Face_Feature/Faces/James_Maslow_35803.jpg
#   inflating: Face_Feature/Faces/Rade_Serbedzija_17082.jpg
#   inflating: Face_Feature/Faces/Alain_Delon_15157.jpg
#   inflating: Face_Feature/Faces/Armand_Assante_30777.jpg
#   inflating: Face_Feature/Faces/Jack_Whitehall_42435.jpg
#   inflating: Face_Feature/Faces/Bob_Barker_8375.jpg
#   inflating: Face_Feature/Faces/Gloria_Steinem_3055.jpg
#   inflating: Face_Feature/Faces/Nazanin_Boniadi_30418.jpg
#   inflating: Face_Feature/Faces/Mia_Wasikowska_49426.jpg
#   inflating: Face_Feature/Faces/Bruno_Ganz_23862.jpg
#   inflating: Face_Feature/Faces/Steven_R._McQueen_43822.jpg
#   inflating: Face_Feature/Faces/Mandy_Patinkin_28675.jpg
#   inflating: Face_Feature/Faces/Greta_Gerwig_35921.jpg
#   inflating: Face_Feature/Faces/Betty_White_26204.jpg
#   inflating: Face_Feature/Faces/Leonor_Watling_2644.jpg
#   inflating: Face_Feature/Faces/Hilarie_Burton_449.jpg
#   inflating: Face_Feature/Faces/Margo_Martindale_17715.jpg
#   inflating: Face_Feature/Faces/Sammy_Davis_Jr._21259.jpg
#   inflating: Face_Feature/Faces/James_Roday_35063.jpg
#   inflating: Face_Feature/Faces/Michael_Shannon_30520.jpg
#   inflating: Face_Feature/Faces/James_Purefoy_32507.jpg
#   inflating: Face_Feature/Faces/Alan_Tudyk_19250.jpg
#   inflating: Face_Feature/Faces/Andre_Braugher_17859.jpg
#   inflating: Face_Feature/Faces/Keri_Hilson_9657.jpg
#   inflating: Face_Feature/Faces/Linda_Lavin_3241.jpg
#   inflating: Face_Feature/Faces/Chiwetel_Ejiofor_16954.jpg
#   inflating: Face_Feature/Faces/Eric_Roberts_41279.jpg
#   inflating: Face_Feature/Faces/Agyness_Deyn_44180.jpg
#   inflating: Face_Feature/Faces/William_Levy_6188.jpg
#   inflating: Face_Feature/Faces/Alan_Rickman_35694.jpg
#   inflating: Face_Feature/Faces/John_Cho_11983.jpg
#   inflating: Face_Feature/Faces/Michael_C._Hall_41787.jpg
#   inflating: Face_Feature/Faces/Lotte_Verbeek_32130.jpg
#   inflating: Face_Feature/Faces/January_Jones_40179.jpg
#   inflating: Face_Feature/Faces/Jillian_Michaels_17093.jpg
#   inflating: Face_Feature/Faces/Jared_Harris_31505.jpg
#   inflating: Face_Feature/Faces/Martine_McCutcheon_20457.jpg
#   inflating: Face_Feature/Faces/Melissa_Rauch_45701.jpg
#   inflating: Face_Feature/Faces/Nadia_Bjorlin_49039.jpg
#   inflating: Face_Feature/Faces/Steve_Carell_35359.jpg
#   inflating: Face_Feature/Faces/Donald_Glover_43339.jpg
#   inflating: Face_Feature/Faces/David_Oyelowo_42392.jpg
#   inflating: Face_Feature/Faces/Josh_Radnor_13669.jpg
#   inflating: Face_Feature/Faces/La_La_Anthony_14211.jpg
#   inflating: Face_Feature/Faces/David_Wenham_589.jpg
#   inflating: Face_Feature/Faces/Michael_Cera_44717.jpg
#   inflating: Face_Feature/Faces/Sonja_Sohn_29057.jpg
#   inflating: Face_Feature/Faces/John_Hodgman_48798.jpg
#   inflating: Face_Feature/Faces/Sonja_Sohn_29051.jpg
#   inflating: Face_Feature/Faces/Kodi_Smit-McPhee_26157.jpg
#   inflating: Face_Feature/Faces/Manish_Dayal_35266.jpg
#   inflating: Face_Feature/Faces/Sanaa_Lathan_28236.jpg
#   inflating: Face_Feature/Faces/Danica_McKellar_36913.jpg
#   inflating: Face_Feature/Faces/Katherine_McNamara_25413.jpg
#   inflating: Face_Feature/Faces/Brian_Blessed_49286.jpg
#   inflating: Face_Feature/Faces/Nelly_Furtado_2685.jpg
#   inflating: Face_Feature/Faces/Johnathon_Schaech_2452.jpg
#   inflating: Face_Feature/Faces/Billie_Joe_Armstrong_38408.jpg
#   inflating: Face_Feature/Faces/Elisabeth_Moss_48687.jpg
#   inflating: Face_Feature/Faces/Jeff_Garlin_6292.jpg
#   inflating: Face_Feature/Faces/Billie_Joe_Armstrong_38404.jpg
#   inflating: Face_Feature/Faces/Simon_Baker_1609.jpg
#   inflating: Face_Feature/Faces/Simon_Baker_1608.jpg
#   inflating: Face_Feature/Faces/Brian_Cox_378.jpg
#   inflating: Face_Feature/Faces/Blake_Shelton_8227.jpg
#   inflating: Face_Feature/Faces/Dave_Foley_21949.jpg
#   inflating: Face_Feature/Faces/Sammy_Davis_Jr._21250.jpg
#   inflating: Face_Feature/Faces/Joan_Allen_38098.jpg
#   inflating: Face_Feature/Faces/Jacob_Latimore_19734.jpg
#   inflating: Face_Feature/Faces/Sofia_Coppola_14637.jpg
#   inflating: Face_Feature/Faces/Katey_Sagal_17149.jpg
#   inflating: Face_Feature/Faces/Gugu_Mbatha-Raw_31280.jpg
#   inflating: Face_Feature/Faces/Sarah_Paulson_20910.jpg
#   inflating: Face_Feature/Faces/Carolyn_Hennesy_6486.jpg
#   inflating: Face_Feature/Faces/Eddie_Izzard_39596.jpg
#   inflating: Face_Feature/Faces/Jerry_Ferrara_12785.jpg
#   inflating: Face_Feature/Faces/Malin_Akerman_41967.jpg
#   inflating: Face_Feature/Faces/Rade_Serbedzija_17063.jpg
#   inflating: Face_Feature/Faces/Walter_Matthau_47359.jpg
#   inflating: Face_Feature/Faces/Jaime_Winstone_40618.jpg
#   inflating: Face_Feature/Faces/Darren_Criss_47448.jpg
#   inflating: Face_Feature/Faces/Ralf_Little_21564.jpg
#   inflating: Face_Feature/Faces/Damon_Lindelof_31928.jpg
#   inflating: Face_Feature/Faces/Taylor_Momsen_29889.jpg
#   inflating: Face_Feature/Faces/Nate_Parker_14976.jpg
#   inflating: Face_Feature/Faces/James_Cosmo_40432.jpg
#   inflating: Face_Feature/Faces/Dan_Fogler_45543.jpg
#   inflating: Face_Feature/Faces/Jeffrey_Wright_6760.jpg
#   inflating: Face_Feature/Faces/Russell_Tovey_10070.jpg
#   inflating: Face_Feature/Faces/Will_Arnett_25862.jpg
#   inflating: Face_Feature/Faces/Jane_Badler_40556.jpg
#   inflating: Face_Feature/Faces/Josh_Peck_37657.jpg
#   inflating: Face_Feature/Faces/Julia_Louis-Dreyfus_44288.jpg
#   inflating: Face_Feature/Faces/Chloe_Bennet_41680.jpg
#   inflating: Face_Feature/Faces/Diego_Luna_915.jpg
#   inflating: Face_Feature/Faces/Joan_Rivers_27073.jpg
#   inflating: Face_Feature/Faces/Kate_Flannery_9084.jpg
#   inflating: Face_Feature/Faces/Oscar_Isaac_38124.jpg
#   inflating: Face_Feature/Faces/Shonda_Rhimes_48857.jpg
#   inflating: Face_Feature/Faces/Paul_Giamatti_40491.jpg
#   inflating: Face_Feature/Faces/Jamel_Debbouze_13592.jpg
#   inflating: Face_Feature/Faces/Nate_Parker_14966.jpg
#   inflating: Face_Feature/Faces/Kyle_Richards_48134.jpg
#   inflating: Face_Feature/Faces/Olga_Kurylenko_18471.jpg
#   inflating: Face_Feature/Faces/Aldis_Hodge_32743.jpg
#   inflating: Face_Feature/Faces/Max_Irons_24816.jpg
#   inflating: Face_Feature/Faces/Cassandra_Peterson_15757.jpg
#   inflating: Face_Feature/Faces/Steven_Yeun_23960.jpg
#   inflating: Face_Feature/Faces/Chazz_Palminteri_46462.jpg
#   inflating: Face_Feature/Faces/Sean_Connery_38274.jpg
#   inflating: Face_Feature/Faces/Michael_Copon_33949.jpg
#   inflating: Face_Feature/Faces/Miranda_Cosgrove_4661.jpg
#   inflating: Face_Feature/Faces/Jenifer_Lewis_41709.jpg
#   inflating: Face_Feature/Faces/La_La_Anthony_14214.jpg
#   inflating: Face_Feature/Faces/Kyle_Richards_48154.jpg
#   inflating: Face_Feature/Faces/Jake_Johnson_35333.jpg
#   inflating: Face_Feature/Faces/Alex_Kingston_16210.jpg
#   inflating: Face_Feature/Faces/Michael_Bay_22227.jpg
#   inflating: Face_Feature/Faces/Jennette_McCurdy_13184.jpg
#   inflating: Face_Feature/Faces/John_Cho_11999.jpg
#   inflating: Face_Feature/Faces/Stana_Katic_13898.jpg
#   inflating: Face_Feature/Faces/Andrea_Riseborough_2243.jpg
#   inflating: Face_Feature/Faces/Angela_Kinsey_23469.jpg
#   inflating: Face_Feature/Faces/Freema_Agyeman_41581.jpg
#   inflating: Face_Feature/Faces/John_Simm_45696.jpg
#   inflating: Face_Feature/Faces/Henry_Cavill_39362.jpg
#   inflating: Face_Feature/Faces/Tamala_Jones_47267.jpg
#   inflating: Face_Feature/Faces/Ken_Jeong_28848.jpg
#   inflating: Face_Feature/Faces/Jim_Sturgess_26793.jpg
#   inflating: Face_Feature/Faces/Guy_Pearce_15306.jpg
#   inflating: Face_Feature/Faces/Abigail_Breslin_1138.jpg
#   inflating: Face_Feature/Faces/Johnny_Galecki_5836.jpg
#   inflating: Face_Feature/Faces/Keeley_Hawes_11939.jpg
#   inflating: Face_Feature/Faces/Allison_Williams_46718.jpg
#   inflating: Face_Feature/Faces/Wendy_Williams_15629.jpg
#   inflating: Face_Feature/Faces/Efren_Ramirez_18570.jpg
#   inflating: Face_Feature/Faces/Chris_Messina_20368.jpg
#   inflating: Face_Feature/Faces/Jake_Abel_31332.jpg
#   inflating: Face_Feature/Faces/Michael_Cudlitz_27391.jpg
#   inflating: Face_Feature/Faces/Sam_Riley_45936.jpg
#   inflating: Face_Feature/Faces/Kylie_Minogue_47215.jpg
#   inflating: Face_Feature/Faces/Jack_Lemmon_5907.jpg
#   inflating: Face_Feature/Faces/Riley_Smith_30554.jpg
#   inflating: Face_Feature/Faces/Vincent_Cassel_14379.jpg
#   inflating: Face_Feature/Faces/Jesse_Metcalfe_18950.jpg
#   inflating: Face_Feature/Faces/David_Kross_32571.jpg
#   inflating: Face_Feature/Faces/Judith_Light_43295.jpg
#   inflating: Face_Feature/Faces/Hector_Elizondo_27505.jpg
#   inflating: Face_Feature/Faces/Lily_Collins_16413.jpg
#   inflating: Face_Feature/Faces/Moran_Atias_10447.jpg
#   inflating: Face_Feature/Faces/Margot_Robbie_48531.jpg
#   inflating: Face_Feature/Faces/Jennifer_Carpenter_1449.jpg
#   inflating: Face_Feature/Faces/Ian_Somerhalder_6519.jpg
#   inflating: Face_Feature/Faces/Quentin_Tarantino_8550.jpg
#   inflating: Face_Feature/Faces/Joan_Cusack_42639.jpg
#   inflating: Face_Feature/Faces/Sarah_Palin_43701.jpg
#   inflating: Face_Feature/Faces/Stana_Katic_13912.jpg
#   inflating: Face_Feature/Faces/Farrah_Abraham_23366.jpg
#   inflating: Face_Feature/Faces/David_Warner_44065.jpg
#   inflating: Face_Feature/Faces/Wendell_Pierce_21370.jpg
#   inflating: Face_Feature/Faces/Robbie_Amell_9077.jpg
#   inflating: Face_Feature/Faces/Mathilda_May_34584.jpg
#   inflating: Face_Feature/Faces/Rob_Corddry_1937.jpg
#   inflating: Face_Feature/Faces/Eddie_Kaye_Thomas_40332.jpg
#   inflating: Face_Feature/Faces/Olivia_Wilde_42795.jpg
#   inflating: Face_Feature/Faces/Mila_Kunis_7988.jpg
#   inflating: Face_Feature/Faces/Tamara_Tunie_49249.jpg
#   inflating: Face_Feature/Faces/Sarah_Wayne_Callies_24934.jpg
#   inflating: Face_Feature/Faces/John_Amos_8194.jpg
#   inflating: Face_Feature/Faces/David_Harewood_24301.jpg
#   inflating: Face_Feature/Faces/Katee_Sackhoff_17739.jpg
#   inflating: Face_Feature/Faces/Kathleen_Robertson_26439.jpg
#   inflating: Face_Feature/Faces/Jeffrey_Donovan_46200.jpg
#   inflating: Face_Feature/Faces/Seth_MacFarlane_10966.jpg
#   inflating: Face_Feature/Faces/Natalie_Zea_31759.jpg
#   inflating: Face_Feature/Faces/Janina_Gavankar_37344.jpg
#   inflating: Face_Feature/Faces/A.R._Rahman_12984.jpg
#   inflating: Face_Feature/Faces/Ryan_Phillippe_7602.jpg
#   inflating: Face_Feature/Faces/Lorenza_Izzo_29006.jpg
#   inflating: Face_Feature/Faces/Paul_Reubens_49447.jpg
#   inflating: Face_Feature/Faces/Katie_Aselton_16132.jpg
#   inflating: Face_Feature/Faces/Aidan_Turner_9373.jpg
#   inflating: Face_Feature/Faces/Victoria_Justice_24521.jpg
#   inflating: Face_Feature/Faces/Sandra_Oh_47635.jpg
#   inflating: Face_Feature/Faces/Edgar_Wright_16575.jpg
#   inflating: Face_Feature/Faces/Freddie_Highmore_38782.jpg
#   inflating: Face_Feature/Faces/Jerry_Ferrara_12782.jpg
#   inflating: Face_Feature/Faces/Morena_Baccarin_18638.jpg
#   inflating: Face_Feature/Faces/Jasmine_Guy_42522.jpg
#   inflating: Face_Feature/Faces/Tom_Selleck_47731.jpg
#   inflating: Face_Feature/Faces/Prince_46159.jpg
#   inflating: Face_Feature/Faces/Johnathon_Schaech_2442.jpg
#   inflating: Face_Feature/Faces/Richard_Ayoade_12061.jpg
#   inflating: Face_Feature/Faces/Melissa_George_49698.jpg
#   inflating: Face_Feature/Faces/Odette_Annable_31472.jpg
#   inflating: Face_Feature/Faces/Kenan_Thompson_23985.jpg
#   inflating: Face_Feature/Faces/Cory_Monteith_25225.jpg
#   inflating: Face_Feature/Faces/Ellen_Wong_47806.jpg
#   inflating: Face_Feature/Faces/Noomi_Rapace_35488.jpg
#   inflating: Face_Feature/Faces/Mario_Lopez_44229.jpg
#   inflating: Face_Feature/Faces/Luke_Arnold_18505.jpg
#   inflating: Face_Feature/Faces/David_Giuntoli_2200.jpg
#   inflating: Face_Feature/Faces/Damon_Wayans_38331.jpg
#   inflating: Face_Feature/Faces/Patrick_Duffy_16570.jpg
#   inflating: Face_Feature/Faces/Paget_Brewster_29795.jpg
#   inflating: Face_Feature/Faces/Sela_Ward_27574.jpg
#   inflating: Face_Feature/Faces/David_Letterman_31096.jpg
#   inflating: Face_Feature/Faces/Kodi_Smit-McPhee_26169.jpg
#   inflating: Face_Feature/Faces/Kal_Penn_39687.jpg
#   inflating: Face_Feature/Faces/Audra_McDonald_5255.jpg
#   inflating: Face_Feature/Faces/Will_Forte_21103.jpg
#   inflating: Face_Feature/Faces/Eartha_Kitt_35162.jpg
#   inflating: Face_Feature/Faces/Martin_Shaw_6083.jpg
#   inflating: Face_Feature/Faces/Usher_Raymond_34504.jpg
#   inflating: Face_Feature/Faces/Sara_Ramirez_36525.jpg
#   inflating: Face_Feature/Faces/Costas_Mandylor_12298.jpg
#   inflating: Face_Feature/Faces/Rami_Malek_46830.jpg
#   inflating: Face_Feature/Faces/William_Fichtner_2772.jpg
#   inflating: Face_Feature/Faces/Yeardley_Smith_40250.jpg
#   inflating: Face_Feature/Faces/Jenifer_Lewis_41728.jpg
#   inflating: Face_Feature/Faces/Irrfan_Khan_34747.jpg
#   inflating: Face_Feature/Faces/Tracy_Morgan_27910.jpg
#   inflating: Face_Feature/Faces/Tom_Ford_4430.jpg
#   inflating: Face_Feature/Faces/Raini_Rodriguez_26822.jpg
#   inflating: Face_Feature/Faces/Alicja_Bachleda_2738.jpg
#   inflating: Face_Feature/Faces/Imelda_Staunton_27944.jpg
#   inflating: Face_Feature/Faces/Pierre_Niney_33170.jpg
#   inflating: Face_Feature/Faces/Ty_Pennington_45113.jpg
#   inflating: Face_Feature/Faces/Domhnall_Gleeson_12169.jpg
#   inflating: Face_Feature/Faces/Sarah_Wayne_Callies_24923.jpg
#   inflating: Face_Feature/Faces/Kel_Mitchell_3398.jpg
#   inflating: Face_Feature/Faces/Amy_Poehler_13212.jpg
#   inflating: Face_Feature/Faces/Ezra_Miller_31586.jpg
#   inflating: Face_Feature/Faces/Tahmoh_Penikett_33137.jpg
#   inflating: Face_Feature/Faces/Jeffrey_Donovan_46210.jpg
#   inflating: Face_Feature/Faces/Cilla_Black_23571.jpg
#   inflating: Face_Feature/Faces/David_Morrissey_23387.jpg
#   inflating: Face_Feature/Faces/Ben_Feldman_23006.jpg
#   inflating: Face_Feature/Faces/Chris_Pine_18286.jpg
#   inflating: Face_Feature/Faces/Monica_Raymund_38961.jpg
#   inflating: Face_Feature/Faces/Tatiana_Maslany_34607.jpg
#   inflating: Face_Feature/Faces/Tim_Burton_27120.jpg
#   inflating: Face_Feature/Faces/Chris_Pine_18275.jpg
#   inflating: Face_Feature/Faces/Zachary_Levi_17688.jpg
#   inflating: Face_Feature/Faces/Steve_Jobs_24083.jpg
#   inflating: Face_Feature/Faces/Edward_Asner_4369.jpg
#   inflating: Face_Feature/Faces/Rory_Kennedy_14115.jpg
#   inflating: Face_Feature/Faces/John_Noble_23710.jpg
#   inflating: Face_Feature/Faces/Ranbir_Kapoor_40298.jpg
#   inflating: Face_Feature/Faces/Lea_Thompson_10195.jpg
#   inflating: Face_Feature/Faces/Rami_Malek_46836.jpg
#   inflating: Face_Feature/Faces/Terence_Stamp_20719.jpg
#   inflating: Face_Feature/Faces/Douglas_Booth_44426.jpg
#   inflating: Face_Feature/Faces/Jack_Black_6422.jpg
#   inflating: Face_Feature/Faces/Cassandra_Peterson_15785.jpg
#   inflating: Face_Feature/Faces/Olivia_Holt_43687.jpg
#   inflating: Face_Feature/Faces/Bill_Nighy_26913.jpg
#   inflating: Face_Feature/Faces/Brendan_Gleeson_43400.jpg
#   inflating: Face_Feature/Faces/Mindy_Kaling_21589.jpg
#   inflating: Face_Feature/Faces/Fergie_28046.jpg
#   inflating: Face_Feature/Faces/Amitabh_Bachchan_41059.jpg
#   inflating: Face_Feature/Faces/Vanilla_Ice_47980.jpg
#   inflating: Face_Feature/Faces/Vince_Gilligan_40705.jpg
#   inflating: Face_Feature/Faces/Zachary_Quinto_24165.jpg
#   inflating: Face_Feature/Faces/Jean-Paul_Belmondo_16139.jpg
#   inflating: Face_Feature/Faces/La_La_Anthony_14229.jpg
#   inflating: Face_Feature/Faces/Zachary_Levi_17674.jpg
#   inflating: Face_Feature/Faces/Marie_Avgeropoulos_3918.jpg
#   inflating: Face_Feature/Faces/Andrea_Riseborough_2252.jpg
#   inflating: Face_Feature/Faces/Martin_Clunes_41878.jpg
#   inflating: Face_Feature/Faces/Stan_Lee_14026.jpg
#   inflating: Face_Feature/Faces/John_Goodman_26699.jpg
#   inflating: Face_Feature/Faces/Jeannie_Mai_30866.jpg
#   inflating: Face_Feature/Faces/Johnny_Galecki_5818.jpg
#   inflating: Face_Feature/Faces/Santiago_Cabrera_21414.jpg
#   inflating: Face_Feature/Faces/John_Goodman_26698.jpg
#   inflating: Face_Feature/Faces/Jon_Huertas_8439.jpg
#   inflating: Face_Feature/Faces/Dan_Fogler_45551.jpg
#   inflating: Face_Feature/Faces/Jesse_Spencer_3763.jpg
#   inflating: Face_Feature/Faces/Vicky_McClure_46020.jpg
#   inflating: Face_Feature/Faces/Tamer_Hassan_28745.jpg
#   inflating: Face_Feature/Faces/Guillaume_Canet_8902.jpg
#   inflating: Face_Feature/Faces/Diane_Kruger_24560.jpg
#   inflating: Face_Feature/Faces/Freddie_Highmore_38780.jpg
#   inflating: Face_Feature/Faces/Ashley_Jensen_5979.jpg
#   inflating: Face_Feature/Faces/John_Simm_45693.jpg
#   inflating: Face_Feature/Faces/Miranda_Lambert_23042.jpg
#   inflating: Face_Feature/Faces/Tahmoh_Penikett_33125.jpg
#   inflating: Face_Feature/Faces/Dawn_Wells_23640.jpg
#   inflating: Face_Feature/Faces/Marie_Osmond_26724.jpg
#   inflating: Face_Feature/Faces/Sidharth_Malhotra_10532.jpg
#   inflating: Face_Feature/Faces/Michael_Cera_44732.jpg
#   inflating: Face_Feature/Faces/Drake_Bell_4136.jpg
#   inflating: Face_Feature/Faces/Hill_Harper_7525.jpg
#   inflating: Face_Feature/Faces/Bridget_Moynahan_37315.jpg
#   inflating: Face_Feature/Faces/Sanaa_Lathan_28262.jpg
#   inflating: Face_Feature/Faces/Bruno_Mars_36872.jpg
#   inflating: Face_Feature/Faces/Riley_Smith_30587.jpg
#   inflating: Face_Feature/Faces/Caity_Lotz_16628.jpg
#   inflating: Face_Feature/Faces/Wendi_McLendon-Covey_14916.jpg
#   inflating: Face_Feature/Faces/Wilson_Cruz_39325.jpg
#   inflating: Face_Feature/Faces/Ingrid_Bergman_35412.jpg
#   inflating: Face_Feature/Faces/Sidse_Babett_Knudsen_37823.jpg
#   inflating: Face_Feature/Faces/Joel_McHale_6683.jpg
#   inflating: Face_Feature/Faces/Christian_Kane_25346.jpg
#   inflating: Face_Feature/Faces/Santiago_Cabrera_21404.jpg
#   inflating: Face_Feature/Faces/Jesse_Spencer_3790.jpg
#   inflating: Face_Feature/Faces/Natalie_Dormer_5514.jpg
#   inflating: Face_Feature/Faces/Ashley_Jensen_5974.jpg
#   inflating: Face_Feature/Faces/Janet_Jackson_5776.jpg
#   inflating: Face_Feature/Faces/Tim_Burton_27149.jpg
#   inflating: Face_Feature/Faces/Gemma_Arterton_12.jpg
#   inflating: Face_Feature/Faces/Jamie_Foxx_29715.jpg
#   inflating: Face_Feature/Faces/Sara_Ramirez_36530.jpg
#   inflating: Face_Feature/Faces/Jared_Harris_31487.jpg
#   inflating: Face_Feature/Faces/Meredith_Baxter_37073.jpg
#   inflating: Face_Feature/Faces/Alan_Cumming_39841.jpg
#   inflating: Face_Feature/Faces/Moran_Atias_10436.jpg
#   inflating: Face_Feature/Faces/Noomi_Rapace_35482.jpg
#   inflating: Face_Feature/Faces/John_Gallagher_Jr._7833.jpg
#   inflating: Face_Feature/Faces/Rami_Malek_46801.jpg
#   inflating: Face_Feature/Faces/Wanda_Sykes_19867.jpg
#   inflating: Face_Feature/Faces/Breckin_Meyer_502.jpg
#   inflating: Face_Feature/Faces/Kelly_Reilly_32869.jpg
#   inflating: Face_Feature/Faces/Neil_deGrasse_Tyson_20526.jpg
#   inflating: Face_Feature/Faces/Greg_Grunberg_16371.jpg
#   inflating: Face_Feature/Faces/Jennette_McCurdy_13198.jpg
#   inflating: Face_Feature/Faces/Ryan_Ochoa_15938.jpg
#   inflating: Face_Feature/Faces/Kristian_Alfonso_22919.jpg
#   inflating: Face_Feature/Faces/Sonam_Kapoor_2412.jpg
#   inflating: Face_Feature/Faces/Kaya_Scodelario_27708.jpg
#   inflating: Face_Feature/Faces/Jean-Marc_Barr_4454.jpg
#   inflating: Face_Feature/Faces/Caterina_Murino_28510.jpg
#   inflating: Face_Feature/Faces/Linda_Gray_37011.jpg
#   inflating: Face_Feature/Faces/Will_Arnett_25849.jpg
#   inflating: Face_Feature/Faces/Hye-kyo_Song_12324.jpg
#   inflating: Face_Feature/Faces/Anthony_Rapp_13379.jpg
#   inflating: Face_Feature/Faces/Adam_Driver_11836.jpg
#   inflating: Face_Feature/Faces/Whitney_Cummings_12208.jpg
#   inflating: Face_Feature/Faces/Lily_Cole_48330.jpg
#   inflating: Face_Feature/Faces/Hugh_Dancy_8421.jpg
#   inflating: Face_Feature/Faces/John_Gallagher_Jr._7810.jpg
#   inflating: Face_Feature/Faces/Drake_Bell_4146.jpg
#   inflating: Face_Feature/Faces/Andrew_Scott_32226.jpg
#   inflating: Face_Feature/Faces/Tinsel_Korey_10739.jpg
#   inflating: Face_Feature/Faces/Jack_Whitehall_42439.jpg
#   inflating: Face_Feature/Faces/Stana_Katic_13917.jpg
#   inflating: Face_Feature/Faces/Jim_Jefferies_11004.jpg
#   inflating: Face_Feature/Faces/Molly_Shannon_10601.jpg
#   inflating: Face_Feature/Faces/Suzanne_Pleshette_18819.jpg
#   inflating: Face_Feature/Faces/Natalie_Martinez_6209.jpg
#   inflating: Face_Feature/Faces/Clive_Owen_38752.jpg
#   inflating: Face_Feature/Faces/Steve_Jobs_24094.jpg
#   inflating: Face_Feature/Faces/Bob_Barker_8372.jpg
#   inflating: Face_Feature/Faces/Charles_S._Dutton_33272.jpg
#   inflating: Face_Feature/Faces/Tom_Selleck_47757.jpg
#   inflating: Face_Feature/Faces/Joss_Whedon_32395.jpg
#   inflating: Face_Feature/Faces/John_Lasseter_3281.jpg
#   inflating: Face_Feature/Faces/Melissa_Rauch_45717.jpg
#   inflating: Face_Feature/Faces/Chris_Pine_18295.jpg
#   inflating: Face_Feature/Faces/Kristen_Bell_14124.jpg
#   inflating: Face_Feature/Faces/Jesse_Metcalfe_18949.jpg
#   inflating: Face_Feature/Faces/David_Koechner_39189.jpg
#   inflating: Face_Feature/Faces/Holliday_Grainger_19614.jpg
#   inflating: Face_Feature/Faces/Anthony_Anderson_33400.jpg
#   inflating: Face_Feature/Faces/William_Levy_6189.jpg
#   inflating: Face_Feature/Faces/Patrick_Fugit_39464.jpg
#   inflating: Face_Feature/Faces/Cheryl_Ladd_32325.jpg
#   inflating: Face_Feature/Faces/Jeff_Daniels_14856.jpg
#   inflating: Face_Feature/Faces/Rob_Brydon_3223.jpg
#   inflating: Face_Feature/Faces/Lolo_Jones_39757.jpg
#   inflating: Face_Feature/Faces/Mary-Louise_Parker_4793.jpg
#   inflating: Face_Feature/Faces/David_Jason_35614.jpg
#   inflating: Face_Feature/Faces/John_Nettles_41552.jpg
#   inflating: Face_Feature/Faces/Terence_Stamp_20728.jpg
#   inflating: Face_Feature/Faces/Hector_Elizondo_27498.jpg
#   inflating: Face_Feature/Faces/Lindsay_Duncan_8033.jpg
#   inflating: Face_Feature/Faces/Pat_Monahan_18350.jpg
#   inflating: Face_Feature/Faces/Jeffrey_Wright_6765.jpg
#   inflating: Face_Feature/Faces/Tom_Kenny_28441.jpg
#   inflating: Face_Feature/Faces/Ted_Danson_40504.jpg
#   inflating: Face_Feature/Faces/Amber_Riley_30237.jpg
#   inflating: Face_Feature/Faces/Mark_Harmon_14522.jpg
#   inflating: Face_Feature/Faces/Woody_Harrelson_6892.jpg
#   inflating: Face_Feature/Faces/Donna_Mills_20765.jpg
#   inflating: Face_Feature/Faces/Missi_Pyle_28386.jpg
#   inflating: Face_Feature/Faces/James_Nesbitt_48598.jpg
#   inflating: Face_Feature/Faces/Natalie_Portman_17987.jpg
#   inflating: Face_Feature/Faces/Yeardley_Smith_40257.jpg
#   inflating: Face_Feature/Faces/Meredith_Baxter_37078.jpg
#   inflating: Face_Feature/Faces/Leslie_Bibb_46735.jpg
#   inflating: Face_Feature/Faces/Paolo_Sorrentino_6927.jpg
#   inflating: Face_Feature/Faces/Terence_Stamp_20709.jpg
#   inflating: Face_Feature/Faces/Marcia_Gay_Harden_20228.jpg
#   inflating: Face_Feature/Faces/Yeardley_Smith_40254.jpg
#   inflating: Face_Feature/Faces/Marc_Blucas_24376.jpg
#   inflating: Face_Feature/Faces/Tamer_Hassan_28728.jpg
#   inflating: Face_Feature/Faces/Olivia_Williams_39272.jpg
#   inflating: Face_Feature/Faces/Rhys_Darby_7021.jpg
#   inflating: Face_Feature/Faces/Jason_Clarke_15075.jpg
#   inflating: Face_Feature/Faces/Sarah_Drew_13541.jpg
#   inflating: Face_Feature/Faces/Andy_Richter_12552.jpg
#   inflating: Face_Feature/Faces/Claudia_Lee_33860.jpg
#   inflating: Face_Feature/Faces/Taylor_Lautner_172.jpg
#   inflating: Face_Feature/Faces/Jason_Clarke_15085.jpg
#   inflating: Face_Feature/Faces/Rob_Reiner_13815.jpg
#   inflating: Face_Feature/Faces/Abigail_Breslin_1123.jpg
#   inflating: Face_Feature/Faces/Kathryn_Joosten_7755.jpg
#   inflating: Face_Feature/Faces/Andre_Braugher_17864.jpg
#   inflating: Face_Feature/Faces/Donna_Murphy_29536.jpg
#   inflating: Face_Feature/Faces/Greg_Grunberg_16364.jpg
#   inflating: Face_Feature/Faces/Reid_Scott_44812.jpg
#   inflating: Face_Feature/Faces/Mallika_Sherawat_21282.jpg
#   inflating: Face_Feature/Faces/Vanessa_Hudgens_48017.jpg
#   inflating: Face_Feature/Faces/Andrea_Riseborough_2273.jpg
#   inflating: Face_Feature/Faces/Ludacris_40912.jpg
#   inflating: Face_Feature/Faces/Hilarie_Burton_448.jpg
#   inflating: Face_Feature/Faces/Will_Poulter_33656.jpg
#   inflating: Face_Feature/Faces/Margo_Martindale_17713.jpg
#   inflating: Face_Feature/Faces/Riz_Ahmed_34445.jpg
#   inflating: Face_Feature/Faces/Hannah_Simone_17506.jpg
#   inflating: Face_Feature/Faces/Robert_Vaughn_25788.jpg
#   inflating: Face_Feature/Faces/Mitchel_Musso_7395.jpg
#   inflating: Face_Feature/Faces/Naturi_Naughton_45165.jpg
#   inflating: Face_Feature/Faces/Jill_Scott_42103.jpg
#   inflating: Face_Feature/Faces/Sonam_Kapoor_2408.jpg
#   inflating: Face_Feature/Faces/Aldis_Hodge_32721.jpg
#   inflating: Face_Feature/Faces/Will_Forte_21085.jpg
#   inflating: Face_Feature/Faces/Randolph_Mantooth_23757.jpg
#   inflating: Face_Feature/Faces/Candice_Patton_31421.jpg
#   inflating: Face_Feature/Faces/Zach_Galifianakis_79.jpg
#   inflating: Face_Feature/Faces/Elle_Fanning_45200.jpg
#   inflating: Face_Feature/Faces/Alan_Tudyk_19247.jpg
#   inflating: Face_Feature/Faces/Tavi_Gevinson_18068.jpg
#   inflating: Face_Feature/Faces/Jack_Coleman_21636.jpg
#   inflating: Face_Feature/Faces/Michael_C._Hall_41778.jpg
#   inflating: Face_Feature/Faces/Christopher_Mintz-Plasse_7864.jpg
#   inflating: Face_Feature/Faces/David_Harewood_24297.jpg
#   inflating: Face_Feature/Faces/Meat_Loaf_35569.jpg
#   inflating: Face_Feature/Faces/Kate_Beckinsale_48174.jpg
#   inflating: Face_Feature/Faces/Olivia_Colman_20568.jpg
#   inflating: Face_Feature/Faces/Matt_Bomer_4326.jpg
#   inflating: Face_Feature/Faces/Robert_Davi_17299.jpg
#   inflating: Face_Feature/Faces/Nick_Thune_19929.jpg
#   inflating: Face_Feature/Faces/Tatyana_Ali_16860.jpg
#   inflating: Face_Feature/Faces/David_Suchet_22412.jpg
#   inflating: Face_Feature/Faces/RZA_16749.jpg
#   inflating: Face_Feature/Faces/Donnie_Yen_24391.jpg
#   inflating: Face_Feature/Faces/Brit_Marling_48501.jpg
#   inflating: Face_Feature/Faces/Alexa_Davalos_19846.jpg
#   inflating: Face_Feature/Faces/Luke_Arnold_18502.jpg
#   inflating: Face_Feature/Faces/Laura_Benanti_23077.jpg
#   inflating: Face_Feature/Faces/Sara_Gilbert_9550.jpg
#   inflating: Face_Feature/Faces/Lucas_Cruikshank_21497.jpg
#   inflating: Face_Feature/Faces/Jon_Huertas_8456.jpg
#   inflating: Face_Feature/Faces/Alba_Rohrwacher_25328.jpg
#   inflating: Face_Feature/Faces/Will_Forte_21081.jpg
#   inflating: Face_Feature/Faces/Luc_Besson_20395.jpg
#   inflating: Face_Feature/Faces/Danny_McBride_43052.jpg
#   inflating: Face_Feature/Faces/Kendra_Wilkinson_48631.jpg
#   inflating: Face_Feature/Faces/Tamer_Hassan_28746.jpg
#   inflating: Face_Feature/Faces/Harry_Treadaway_6586.jpg
#   inflating: Face_Feature/Faces/Kenan_Thompson_24020.jpg
#   inflating: Face_Feature/Faces/Titus_Welliver_38646.jpg
#   inflating: Face_Feature/Faces/Tamera_Mowry-Housley_12878.jpg
#   inflating: Face_Feature/Faces/Daniel_Craig_1777.jpg
#   inflating: Face_Feature/Faces/Olivia_Wilde_42816.jpg
#   inflating: Face_Feature/Faces/RZA_16757.jpg
#   inflating: Face_Feature/Faces/Marc_Forster_27597.jpg
#   inflating: Face_Feature/Faces/Kendra_Wilkinson_48619.jpg
#   inflating: Face_Feature/Faces/David_Oyelowo_42389.jpg
#   inflating: Face_Feature/Faces/Lea_Michele_7889.jpg
#   inflating: Face_Feature/Faces/Kelly_Rutherford_8038.jpg
#   inflating: Face_Feature/Faces/Noel_Clarke_7481.jpg
#   inflating: Face_Feature/Faces/Drea_de_Matteo_15859.jpg
#   inflating: Face_Feature/Faces/Breckin_Meyer_518.jpg
#   inflating: Face_Feature/Faces/David_Warner_44063.jpg
#   inflating: Face_Feature/Faces/Caity_Lotz_16625.jpg
#   inflating: Face_Feature/Faces/Nikolaj_Coster-Waldau_44760.jpg
#   inflating: Face_Feature/Faces/Natalie_Martinez_6227.jpg
#   inflating: Face_Feature/Faces/Janine_Turner_9934.jpg
#   inflating: Face_Feature/Faces/Fergie_28071.jpg
#   inflating: Face_Feature/Faces/Jesse_Eisenberg_15425.jpg
#   inflating: Face_Feature/Faces/Shiri_Appleby_28969.jpg
#   inflating: Face_Feature/Faces/Blake_Michael_13305.jpg
#   inflating: Face_Feature/Faces/Paul_Sorvino_20188.jpg
#   inflating: Face_Feature/Faces/Mischa_Barton_25653.jpg
#   inflating: Face_Feature/Faces/Aamir_Khan_47000.jpg
#   inflating: Face_Feature/Faces/Lea_Salonga_27087.jpg
#   inflating: Face_Feature/Faces/Gordon_Ramsay_33796.jpg
#   inflating: Face_Feature/Faces/John_Hawkes_49779.jpg
#   inflating: Face_Feature/Faces/Eric_Roberts_41275.jpg
#   inflating: Face_Feature/Faces/Jerry_Trainor_42270.jpg
# ...
#   inflating: Face_Feature/Faces/Janet_Montgomery_14701.jpg
#   inflating: Face_Feature/Faces/Vincent_Cassel_14376.jpg
#   inflating: Face_Feature/Faces/Sam_Worthington_35846.jpg
#   inflating: Face_Feature/Faces/Matt_Smith_31145.jpg
#   inflating: Face_Feature/Faces/Tyler_Blackburn_17012.jpg
#   inflating: Face_Feature/Faces/Ben_Feldman_23008.jpg
#   inflating: Face_Feature/Faces/Chloe_Dykstra_47518.jpg
#   inflating: Face_Feature/Faces/Michaela_Conlin_7638.jpg
#   inflating: Face_Feature/Faces/Ben_Whishaw_7445.jpg
#   inflating: Face_Feature/Faces/Ryan_Ochoa_15945.jpg
#   inflating: Face_Feature/Faces/Michael_Trevino_13734.jpg
#   inflating: Face_Feature/Faces/Miriam_Margolyes_5646.jpg
#   inflating: Face_Feature/Faces/Ellen_Burstyn_43446.jpg
#   inflating: Face_Feature/Faces/Danny_Pino_24857.jpg
#   inflating: Face_Feature/Faces/Donald_Glover_43351.jpg
#   inflating: Face_Feature/Faces/Wendy_Williams_15603.jpg
#   inflating: Face_Feature/Faces/James_Purefoy_32497.jpg
#   inflating: Face_Feature/Faces/Josh_Henderson_45739.jpg
#   inflating: Face_Feature/Faces/Lolo_Jones_39769.jpg
#   inflating: Face_Feature/Faces/Wim_Wenders_17874.jpg
#   inflating: Face_Feature/Faces/Dan_Stevens_43973.jpg
#   inflating: Face_Feature/Faces/Michelle_Williams_44629.jpg
#   inflating: Face_Feature/Faces/Bingbing_Li_16002.jpg
#   inflating: Face_Feature/Faces/Jordan_Gavaris_46580.jpg
#   inflating: Face_Feature/Faces/Ernie_Hudson_6674.jpg
#   inflating: Face_Feature/Faces/Laura_Haddock_34972.jpg
#   inflating: Face_Feature/Faces/Zachary_Gordon_49531.jpg
#   inflating: Face_Feature/Faces/Jasika_Nicole_25897.jpg
#   inflating: Face_Feature/Faces/Lolo_Jones_39750.jpg
#   inflating: Face_Feature/Faces/Corbin_Bleu_33633.jpg
#   inflating: Face_Feature/Faces/Jillian_Harris_48251.jpg
#   inflating: Face_Feature/Faces/Antonio_Cupo_618.jpg
#   inflating: Face_Feature/Faces/Sam_Trammell_754.jpg
#   inflating: Face_Feature/Faces/Luke_Newberry_15354.jpg
#   inflating: Face_Feature/Faces/Jemaine_Clement_18157.jpg
#   inflating: Face_Feature/Faces/John_Hodgman_48766.jpg
#   inflating: Face_Feature/Faces/Casey_Affleck_9751.jpg
#   inflating: Face_Feature/Faces/Ana_Gasteyer_48661.jpg
#   inflating: Face_Feature/Faces/David_Mamet_3608.jpg
#   inflating: Face_Feature/Faces/Skylar_Astin_39119.jpg
#   inflating: Face_Feature/Faces/Guillaume_Canet_8917.jpg
#   inflating: Face_Feature/Faces/Geri_Halliwell_42054.jpg
#   inflating: Face_Feature/Faces/John_Amos_8173.jpg
#   inflating: Face_Feature/Faces/Rose_McIver_18845.jpg
#   inflating: Face_Feature/Faces/Maggie_Gyllenhaal_2572.jpg
#   inflating: Face_Feature/Faces/Chiwetel_Ejiofor_16966.jpg
#   inflating: Face_Feature/Faces/Adrianne_Palicki_15952.jpg
#   inflating: Face_Feature/Faces/Dylan_McDermott_3836.jpg
#   inflating: Face_Feature/Faces/Titus_Welliver_38633.jpg
#   inflating: Face_Feature/Faces/Eric_McCormack_11628.jpg
#   inflating: Face_Feature/Faces/Edward_Asner_4386.jpg
#   inflating: Face_Feature/Faces/Roma_Downey_3160.jpg
#   inflating: Face_Feature/Faces/Josh_Peck_37644.jpg
#   inflating: Face_Feature/Faces/Alex_Borstein_41149.jpg
#   inflating: Face_Feature/Faces/Ruta_Lee_45231.jpg
#   inflating: Face_Feature/Faces/Pierfrancesco_Favino_2136.jpg
#   inflating: Face_Feature/Faces/Caroline_Rhea_9234.jpg
#   inflating: Face_Feature/Faces/Russell_Peters_14302.jpg
#   inflating: Face_Feature/Faces/Christina_Hendricks_4802.jpg
#   inflating: Face_Feature/Faces/Ginger_Rogers_44153.jpg
#   inflating: Face_Feature/Faces/Jordana_Brewster_13982.jpg
#   inflating: Face_Feature/Faces/Melora_Hardin_42731.jpg
#   inflating: Face_Feature/Faces/Zachary_Gordon_49533.jpg
#   inflating: Face_Feature/Faces/Hector_Elizondo_27487.jpg
#   inflating: Face_Feature/Faces/Joel_Kinnaman_29231.jpg
#   inflating: Face_Feature/Faces/David_Kross_32561.jpg
#   inflating: Face_Feature/Faces/Vanessa_Hudgens_48020.jpg
#   inflating: Face_Feature/Faces/Joan_Cusack_42622.jpg
#   inflating: Face_Feature/Faces/Peter_Jackson_33202.jpg
#   inflating: Face_Feature/Faces/Paolo_Sorrentino_6937.jpg
#   inflating: Face_Feature/Faces/Pete_Wentz_13243.jpg
#   inflating: Face_Feature/Faces/Sendhil_Ramamurthy_19654.jpg
#   inflating: Face_Feature/Faces/Charlotte_Gainsbourg_45396.jpg
#   inflating: Face_Feature/Faces/Loretta_Swit_417.jpg
#   inflating: Face_Feature/Faces/Diego_Klattenhoff_41852.jpg
#   inflating: Face_Feature/Faces/David_Letterman_31082.jpg
#   inflating: Face_Feature/Faces/Drea_de_Matteo_15844.jpg
#   inflating: Face_Feature/Faces/Goran_Visnjic_42663.jpg
#   inflating: Face_Feature/Faces/David_Zayas_10332.jpg
#   inflating: Face_Feature/Faces/Seth_Rogen_17590.jpg
#   inflating: Face_Feature/Faces/Amaury_Nolasco_37556.jpg
#   inflating: Face_Feature/Faces/Charlotte_Gainsbourg_45395.jpg
#   inflating: Face_Feature/Faces/Tahj_Mowry_30090.jpg
#   inflating: Face_Feature/Faces/Victoria_Rowell_44697.jpg
#   inflating: Face_Feature/Faces/Julia_Stiles_13070.jpg
#   inflating: Face_Feature/Faces/Pablo_Schreiber_15802.jpg
#   inflating: Face_Feature/Faces/Kirsten_Vangsness_33727.jpg
#   inflating: Face_Feature/Faces/Christina_Ricci_29305.jpg
#   inflating: Face_Feature/Faces/Chloe_Dykstra_47492.jpg
#   inflating: Face_Feature/Faces/Eoin_Macken_4018.jpg
#   inflating: Face_Feature/Faces/Kevin_McHale_29455.jpg
#   inflating: Face_Feature/Faces/Julianne_Hough_3453.jpg
#   inflating: Face_Feature/Faces/Eric_Roberts_41270.jpg
#   inflating: Face_Feature/Faces/Tatiana_Maslany_34633.jpg
#   inflating: Face_Feature/Faces/Doutzen_Kroes_26993.jpg
#   inflating: Face_Feature/Faces/Zac_Efron_40384.jpg
#   inflating: Face_Feature/Faces/Karoline_Herfurth_34713.jpg
#   inflating: Face_Feature/Faces/Tamala_Jones_47254.jpg
#   inflating: Face_Feature/Faces/Peter_Facinelli_26647.jpg
#   inflating: Face_Feature/Faces/Stephen_Fry_33547.jpg
#   inflating: Face_Feature/Faces/Noah_Emmerich_41932.jpg
#   inflating: Face_Feature/Faces/Freida_Pinto_3516.jpg
#   inflating: Face_Feature/Faces/Joel_McHale_6678.jpg
#   inflating: Face_Feature/Faces/Vanessa_Marcil_34665.jpg
#   inflating: Face_Feature/Faces/Tilda_Swinton_45651.jpg
#   inflating: Face_Feature/Faces/Andrew_Lee_Potts_36173.jpg
#   inflating: Face_Feature/Faces/Dawn_French_9347.jpg
#   inflating: Face_Feature/Faces/Nadia_Bjorlin_49036.jpg
#   inflating: Face_Feature/Faces/Kathryn_Hahn_46317.jpg
#   inflating: Face_Feature/Faces/William_Baldwin_1987.jpg
#   inflating: Face_Feature/Faces/Mark_Webber_37457.jpg
#   inflating: Face_Feature/Faces/Charice_38579.jpg
#   inflating: Face_Feature/Faces/Elodie_Yung_36185.jpg
#   inflating: Face_Feature/Faces/Andrea_Riseborough_2262.jpg
#   inflating: Face_Feature/Faces/Toby_Jones_25671.jpg
#   inflating: Face_Feature/Faces/Sanaa_Lathan_28252.jpg
#   inflating: Face_Feature/Faces/Janet_Montgomery_14705.jpg
#   inflating: Face_Feature/Faces/Paul_Feig_34109.jpg
#   inflating: Face_Feature/Faces/Bill_Pullman_10869.jpg
#   inflating: Face_Feature/Faces/Rene_Auberjonois_31595.jpg
#   inflating: Face_Feature/Faces/Miranda_Kerr_15468.jpg
#   inflating: Face_Feature/Faces/Alan_Alda_23676.jpg
#   inflating: Face_Feature/Faces/John_Goodman_26674.jpg
#   inflating: Face_Feature/Faces/James_Maslow_35800.jpg
#   inflating: Face_Feature/Faces/Matthew_Fox_30143.jpg
#   inflating: Face_Feature/Faces/Joan_Chen_11239.jpg
#   inflating: Face_Feature/Faces/Alexander_Siddig_8822.jpg
#   inflating: Face_Feature/Faces/Mila_Kunis_7995.jpg
#   inflating: Face_Feature/Faces/Ernie_Hudson_6669.jpg
#   inflating: Face_Feature/Faces/Matthew_Lillard_25799.jpg
#   inflating: Face_Feature/Faces/Michael_K._Williams_43890.jpg
#   inflating: Face_Feature/Faces/John_Goodman_26684.jpg
#   inflating: Face_Feature/Faces/David_Mamet_3622.jpg
#   inflating: Face_Feature/Faces/Ruth_Jones_28229.jpg
#   inflating: Face_Feature/Faces/Paul_Giamatti_40484.jpg
#   inflating: Face_Feature/Faces/Raini_Rodriguez_26799.jpg
#   inflating: Face_Feature/Faces/Rade_Serbedzija_17085.jpg
#   inflating: Face_Feature/Faces/Kelly_Macdonald_7049.jpg
#   inflating: Face_Feature/Faces/Melissa_McCarthy_26432.jpg
#   inflating: Face_Feature/Faces/Naomie_Harris_40020.jpg
#   inflating: Face_Feature/Faces/Vanessa_Hudgens_48011.jpg
#   inflating: Face_Feature/Faces/Terrence_Howard_27757.jpg
#   inflating: Face_Feature/Faces/Nina_Arianda_4553.jpg
#   inflating: Face_Feature/Faces/Sheridan_Smith_46941.jpg
#   inflating: Face_Feature/Faces/Linda_Lavin_3249.jpg
#   inflating: Face_Feature/Faces/Russell_Tovey_10067.jpg
#   inflating: Face_Feature/Faces/Jean-Paul_Belmondo_16150.jpg
#   inflating: Face_Feature/Faces/Kate_Walsh_4847.jpg
#   inflating: Face_Feature/Faces/Marie_Avgeropoulos_3881.jpg
#   inflating: Face_Feature/Faces/Roma_Downey_3195.jpg
#   inflating: Face_Feature/Faces/Kate_Mulgrew_28003.jpg
#   inflating: Face_Feature/Faces/Jeff_Daniels_14831.jpg
#   inflating: Face_Feature/Faces/John_Turturro_20605.jpg
#   inflating: Face_Feature/Faces/Paul_Feig_34074.jpg
#   inflating: Face_Feature/Faces/Hunter_Parrish_26035.jpg
#   inflating: Face_Feature/Faces/Jennifer_Esposito_44894.jpg
#   inflating: Face_Feature/Faces/Jen_Lilley_20490.jpg
#   inflating: Face_Feature/Faces/Martin_Henderson_1257.jpg
#   inflating: Face_Feature/Faces/America_Ferrera_17228.jpg
#   inflating: Face_Feature/Faces/Kelli_Berglund_20082.jpg
#   inflating: Face_Feature/Faces/Rita_Ora_7182.jpg
#   inflating: Face_Feature/Faces/Heidi_Montag_42738.jpg
#   inflating: Face_Feature/Faces/James_Earl_Jones_27227.jpg
#   inflating: Face_Feature/Faces/Jamel_Debbouze_13576.jpg
#   inflating: Face_Feature/Faces/Walton_Goggins_33361.jpg
#   inflating: Face_Feature/Faces/David_Mamet_3618.jpg
#   inflating: Face_Feature/Faces/Loretta_Devine_17352.jpg
#   inflating: Face_Feature/Faces/Teri_Hatcher_12716.jpg
#   inflating: Face_Feature/Faces/Michael_Cudlitz_27360.jpg
#   inflating: Face_Feature/Faces/January_Jones_40195.jpg
#   inflating: Face_Feature/Faces/Douglas_Booth_44427.jpg
#   inflating: Face_Feature/Faces/Jon_Pertwee_42948.jpg
#   inflating: Face_Feature/Faces/Jennifer_Saunders_30379.jpg
#   inflating: Face_Feature/Faces/Denis_Leary_3129.jpg
#   inflating: Face_Feature/Faces/Kelly_Rutherford_8061.jpg
#   inflating: Face_Feature/Faces/Jack_Coleman_21663.jpg
#   inflating: Face_Feature/Faces/Doutzen_Kroes_26976.jpg
#   inflating: Face_Feature/Faces/Steve_Carell_35357.jpg
#   inflating: Face_Feature/Faces/Katherine_McNamara_25386.jpg
#   inflating: Face_Feature/Faces/Gillian_Jacobs_47173.jpg
#   inflating: Face_Feature/Faces/Manish_Dayal_35276.jpg
#   inflating: Face_Feature/Faces/Miriam_Margolyes_5660.jpg
#   inflating: Face_Feature/Faces/Pete_Wentz_13271.jpg
#   inflating: Face_Feature/Faces/Rob_Corddry_1956.jpg
#   inflating: Face_Feature/Faces/Jamie_Chung_22546.jpg
#   inflating: Face_Feature/Faces/Ang_Lee_44361.jpg
#   inflating: Face_Feature/Faces/Greer_Garson_2084.jpg
#   inflating: Face_Feature/Faces/Leslie_Bibb_46739.jpg
#   inflating: Face_Feature/Faces/Eoin_Macken_4032.jpg
#   inflating: Face_Feature/Faces/Dick_Van_Dyke_41517.jpg
#   inflating: Face_Feature/Faces/Jessica_Lowndes_20977.jpg
#   inflating: Face_Feature/Faces/Nathalie_Emmanuel_13349.jpg
#   inflating: Face_Feature/Faces/Jorja_Fox_30158.jpg
#   inflating: Face_Feature/Faces/Jeffrey_Tambor_31720.jpg
#   inflating: Face_Feature/Faces/Sam_Heughan_42175.jpg
#   inflating: Face_Feature/Faces/Rooney_Mara_49102.jpg
#   inflating: Face_Feature/Faces/Gilles_Marini_7690.jpg
#   inflating: Face_Feature/Faces/David_Letterman_31088.jpg
#   inflating: Face_Feature/Faces/Heather_Graham_31801.jpg
#   inflating: Face_Feature/Faces/Sharni_Vinson_32797.jpg
#   inflating: Face_Feature/Faces/Sophie_Okonedo_47363.jpg
#   inflating: Face_Feature/Faces/Mia_Wasikowska_49412.jpg
#   inflating: Face_Feature/Faces/Thomas_Haden_Church_36368.jpg
#   inflating: Face_Feature/Faces/Leonor_Watling_2673.jpg
#   inflating: Face_Feature/Faces/Joan_Rivers_27060.jpg
#   inflating: Face_Feature/Faces/Michael_K._Williams_43887.jpg
#   inflating: Face_Feature/Faces/Zack_Snyder_23908.jpg
#   inflating: Face_Feature/Faces/Evanna_Lynch_38008.jpg
#   inflating: Face_Feature/Faces/Santiago_Cabrera_21388.jpg
#   inflating: Face_Feature/Faces/Joseph_Gordon-Levitt_39095.jpg
#   inflating: Face_Feature/Faces/Nathaniel_Buzolic_32659.jpg
#   inflating: Face_Feature/Faces/Fiona_Shaw_2557.jpg
#   inflating: Face_Feature/Faces/Danny_Pino_24848.jpg
#   inflating: Face_Feature/Faces/Cyndi_Lauper_22468.jpg
#   inflating: Face_Feature/Faces/Seth_Meyers_49812.jpg
#   inflating: Face_Feature/Faces/Fred_Williamson_20646.jpg
#   inflating: Face_Feature/Faces/Misha_Collins_46084.jpg
#   inflating: Face_Feature/Faces/Jennifer_Carpenter_1444.jpg
#   inflating: Face_Feature/Faces/Naturi_Naughton_45157.jpg
#   inflating: Face_Feature/Faces/Candice_Accola_42858.jpg
#   inflating: Face_Feature/Faces/Tony_Curran_32307.jpg
#   inflating: Face_Feature/Faces/Akshay_Kumar_11572.jpg
#   inflating: Face_Feature/Faces/Zachary_Gordon_49528.jpg
#   inflating: Face_Feature/Faces/Scott_Bakula_24143.jpg
#   inflating: Face_Feature/Faces/Dan_Aykroyd_15649.jpg
#   inflating: Face_Feature/Faces/Troye_Sivan_24771.jpg
#   inflating: Face_Feature/Faces/Andrew_Dice_Clay_44494.jpg
#   inflating: Face_Feature/Faces/Tatyana_Ali_16871.jpg
#   inflating: Face_Feature/Faces/CCH_Pounder_4046.jpg
#   inflating: Face_Feature/Faces/Cameron_Boyce_10287.jpg
#   inflating: Face_Feature/Faces/Zulay_Henao_9456.jpg
#   inflating: Face_Feature/Faces/Melissa_Peterman_30228.jpg
#   inflating: Face_Feature/Faces/Efren_Ramirez_18555.jpg
#   inflating: Face_Feature/Faces/Candace_Cameron_Bure_28787.jpg
#   inflating: Face_Feature/Faces/J.K._Simmons_11714.jpg
#   inflating: Face_Feature/Faces/Iain_Glen_27235.jpg
#   inflating: Face_Feature/Faces/John_Larroquette_18126.jpg
#   inflating: Face_Feature/Faces/Niall_Horan_45318.jpg
#   inflating: Face_Feature/Faces/Taraji_P._Henson_29269.jpg
#   inflating: Face_Feature/Faces/Danny_McBride_43042.jpg
#   inflating: Face_Feature/Faces/Sofia_Coppola_14667.jpg
#   inflating: Face_Feature/Faces/Norman_Reedus_9844.jpg
#   inflating: Face_Feature/Faces/Elle_Fanning_45188.jpg
#   inflating: Face_Feature/Faces/Dermot_Mulroney_25735.jpg
#   inflating: Face_Feature/Faces/Eddie_Kaye_Thomas_40307.jpg
#   inflating: Face_Feature/Faces/Theo_Rossi_9405.jpg
#   inflating: Face_Feature/Faces/Giovanni_Ribisi_47077.jpg
#   inflating: Face_Feature/Faces/Shraddha_Kapoor_10171.jpg
#   inflating: Face_Feature/Faces/Marion_Ross_18085.jpg
#   inflating: Face_Feature/Faces/Simon_Callow_1205.jpg
#   inflating: Face_Feature/Faces/Adam_Brody_6612.jpg
#   inflating: Face_Feature/Faces/Jacqueline_Fernandez_11077.jpg
#   inflating: Face_Feature/Faces/Patrick_Duffy_16535.jpg
#   inflating: Face_Feature/Faces/Rebecca_Mader_45997.jpg
#   inflating: Face_Feature/Faces/Hugh_Jackman_11917.jpg
#   inflating: Face_Feature/Faces/Douglas_Booth_44435.jpg
#   inflating: Face_Feature/Faces/Rob_Riggle_25167.jpg
#   inflating: Face_Feature/Faces/Jean-Marc_Barr_4479.jpg
#   inflating: Face_Feature/Faces/Nathaniel_Buzolic_32672.jpg
#   inflating: Face_Feature/Faces/Kangana_Ranaut_6269.jpg
#   inflating: Face_Feature/Faces/Brett_Davern_5399.jpg
#   inflating: Face_Feature/Faces/John_Hawkes_49781.jpg
#   inflating: Face_Feature/Faces/CCH_Pounder_4062.jpg
#   inflating: Face_Feature/Faces/Neal_McDonough_5046.jpg
#   inflating: Face_Feature/Faces/Lauryn_Hill_26102.jpg
#   inflating: Face_Feature/Faces/Helena_Bonham_Carter_11808.jpg
#   inflating: Face_Feature/Faces/Chace_Crawford_40579.jpg
#   inflating: Face_Feature/Faces/James_Lipton_37812.jpg
#   inflating: Face_Feature/Faces/Marcia_Cross_9187.jpg
#   inflating: Face_Feature/Faces/Hector_Elizondo_27502.jpg
#   inflating: Face_Feature/Faces/Steve_Carell_35360.jpg
#   inflating: Face_Feature/Faces/Rose_McIver_18868.jpg
#   inflating: Face_Feature/Faces/Jennifer_Saunders_30385.jpg
#   inflating: Face_Feature/Faces/Janet_Montgomery_14677.jpg
#   inflating: Face_Feature/Faces/Matthew_Lillard_25819.jpg

# %%
# !wget http://www.robots.ox.ac.uk/~vgg/research/CMBiometrics/data/zippedFaces.tar.gz 
# tar zxvf zippedFaces.tar.gz -C "/content/drive/My Drive/Speech2Face/vox1_dataset/"

# %%
# !curl --user voxceleb1912:0s42xuw6 -o "/content/drive/My Drive/Speech2Face/ff/vox.zip" http://www.robots.ox.ac.uk/~vgg/data/voxceleb/vox1a/vox1_test_wav.zip

# %%
import glob

import numpy as np
import sys

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import  torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from face_recognition import face_landmarks, face_locations, face_encodings
from random import randint
from random import shuffle

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim

import os
from os.path import join
from os import listdir

from tqdm import tqdm
from google.colab.patches import cv2_imshow
import cv2

# %%
# Reproducibility stuff

import random
torch.manual_seed(42)
np.random.seed(42)
random.seed(0)

# %%
# This dataset use .npy embedding VGG
def load_metadata(data_file_path):
    data_list = []
    with open(data_file_path, "r") as f:
        for line in f:
            data_list.append(line.rstrip("\n").split(","))
    return data_list


class _Normalize_Tensor(object):
    def __init__(self, color_mean, color_std):
        self.color_mean = color_mean
        self.color_std = color_std

    def __call__(self, img):
        # Convert image to Tensor
        img = transforms.functional.to_tensor(img)

        # Normalize image by the parameter of pre-trained face-encoder
        img = transforms.functional.normalize(
            img, self.color_mean, self.color_std)

        return img

class EmbedImagePairs(Dataset):
    def __init__(self, data_list_path, size=64):
        super().__init__()
        self.face_features = np.load(join(data_list_path,'facefeature.npy'))
        self.image_path = join(data_list_path, 'Faces')
        self.images =  listdir(join(data_list_path, 'Faces'))
        shuffle(self.images)
        self.images = self.images[42000:42600]
        
        self.size = size


        self.transform_fd = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor()
        ])
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        # Load face-image
        image_p = self.images[idx]
        features_index = int(image_p.split('_')[-1].split('.')[0])

        image = Image.open(join(self.image_path,image_p))
        
        
        # image_ = image.resize((224,224))
        # Localize Face
        np_image = np.array(image)
        # print(np_image.shape)
        try:

          resultant = []
          #np_image = np_image[x:x1,y:y1]
          landmark = face_landmarks(np_image)
          for i in list(landmark[0].keys()):
            resultant += landmark[0][i]
          landmark = np.ravel(np.array(resultant))

        except IndexError:
          return self[randint(0, len(self))]

        face_vectors = torch.tensor(self.face_features[features_index])

        return face_vectors.float(), torch.tensor(landmark).float(), self.transform_fd(image)

# %%
class Vgg_face_dag(nn.Module):

    def __init__(self):
        super(Vgg_face_dag, self).__init__()
        self.meta = {'mean': [129.186279296875, 104.76238250732422, 93.59396362304688],
                     'std': [1, 1, 1],
                     'imageSize': [224, 224, 3]}
        self.conv1_1 = nn.Conv2d(3, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_1 = nn.ReLU(inplace=True)
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_2 = nn.ReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_1 = nn.ReLU(inplace=True)
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_2 = nn.ReLU(inplace=True)
        self.pool2 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_1 = nn.ReLU(inplace=True)
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_2 = nn.ReLU(inplace=True)
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_3 = nn.ReLU(inplace=True)
        self.pool3 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_1 = nn.ReLU(inplace=True)
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_2 = nn.ReLU(inplace=True)
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_3 = nn.ReLU(inplace=True)
        self.pool4 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_1 = nn.ReLU(inplace=True)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_2 = nn.ReLU(inplace=True)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_3 = nn.ReLU(inplace=True)
        self.pool5 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.fc6 = nn.Linear(in_features=25088, out_features=4096, bias=True)
        self.relu6 = nn.ReLU(inplace=True)
        self.dropout6 = nn.Dropout(p=0.5)
        self.fc7 = nn.Linear(in_features=4096, out_features=4096, bias=True)
        self.relu7 = nn.ReLU(inplace=True)
        self.dropout7 = nn.Dropout(p=0.5)
        self.fc8 = nn.Linear(in_features=4096, out_features=2622, bias=True)

    def forward(self, x0, is_fc8=False):
        x1 = self.conv1_1(x0)
        x2 = self.relu1_1(x1)
        x3 = self.conv1_2(x2)
        x4 = self.relu1_2(x3)
        x5 = self.pool1(x4)
        x6 = self.conv2_1(x5)
        x7 = self.relu2_1(x6)
        x8 = self.conv2_2(x7)
        x9 = self.relu2_2(x8)
        x10 = self.pool2(x9)
        x11 = self.conv3_1(x10)
        x12 = self.relu3_1(x11)
        x13 = self.conv3_2(x12)
        x14 = self.relu3_2(x13)
        x15 = self.conv3_3(x14)
        x16 = self.relu3_3(x15)
        x17 = self.pool3(x16)
        x18 = self.conv4_1(x17)
        x19 = self.relu4_1(x18)
        x20 = self.conv4_2(x19)
        x21 = self.relu4_2(x20)
        x22 = self.conv4_3(x21)
        x23 = self.relu4_3(x22)
        x24 = self.pool4(x23)
        x25 = self.conv5_1(x24)
        x26 = self.relu5_1(x25)
        x27 = self.conv5_2(x26)
        x28 = self.relu5_2(x27)
        x29 = self.conv5_3(x28)
        x30 = self.relu5_3(x29)
        x31_preflatten = self.pool5(x30)
        x31 = x31_preflatten.view(x31_preflatten.size(0), -1)
        x32 = self.fc6(x31)
        x33 = self.relu6(x32)
        x34 = self.dropout6(x33)
        x35 = self.fc7(x34)
        x36 = self.relu7(x35)
        x37 = self.dropout7(x36)
        if is_fc8:
            x38 = self.fc8(x37)
        else:
            x38 = x37
        return x38


def vgg_face_dag(weights_path=None, **kwargs):
    """
    load imported model instance
    Args:
        weights_path (str): If set, loads model weights from the given path
    """
    model = Vgg_face_dag()
    if weights_path:
        state_dict = torch.load(weights_path)
        model.load_state_dict(state_dict)
    return model

# %%
class DECODER(nn.Module):
    def __init__(self, phase):
        super(DECODER, self).__init__()
        self.phase = phase
        self.fc3 = nn.Linear(4096, 1000)
        self.ReLU = nn.ReLU()
        #self.fc_bn3 = nn.BatchNorm1d(1000)


        self.fc4 = nn.Linear(1000, 14 * 14 * 256)
        self.fc_bn4 = nn.BatchNorm1d(14 * 14 * 256)
        def TransConv( i, kernal = 5, stride = 2, inp = None):
            if not inp:
                inp = max(256//2**(i-1), 32)

            layer =  nn.Sequential(
                nn.ConvTranspose2d(inp, max(256//2**i, 32), 
                                kernal, stride=stride, padding=2, output_padding=1, 
                                dilation=1, padding_mode='zeros'),
                nn.ReLU(),
                nn.BatchNorm2d(max(256//2**i, 32)))
            return layer
        self.T1_ = TransConv(1, inp = 256)
        self.T2_ = TransConv(2)
        self.T3_ = TransConv(3)
        self.T4_ = TransConv(4)
    
        self.ConvLast = nn.Sequential(
            nn.Conv2d(32, 3, (1,1), stride=1),
            nn.BatchNorm2d(3),
            nn.ReLU())


        self.layerLandmark1 = nn.Linear(1000, 800)
        self.layerLandmark2 = nn.Linear(800, 600)
        self.layerLandmark3 = nn.Linear(600, 400)
        self.layerLandmark4 = nn.Linear(400, 200)
        self.layerLandmark5 = nn.Linear(200, 144)

    def forward(self, x):
        L1 = self.fc3(x)
        L1 = self.ReLU(L1)


        L2 = self.layerLandmark1(L1)
        L2 = self.ReLU(L2)

        L3 = self.layerLandmark2(L2)
        L3 = self.ReLU(L3)

        L4 = self.layerLandmark3(L3)
        L4 = self.ReLU(L4)

        L5 = self.layerLandmark4(L4)
        L5 = self.ReLU(L5)

        L6 = self.layerLandmark5(L5)
        outL = self.ReLU(L6)


        # B1 = self.fc_bn3(L1) 
        T0 = self.fc4(L1) 
        T0 = self.ReLU(T0)
        # T0 = self.fc_bn4(T0)
        T0 = T0.view(-1,256,14,14)



        T1 = self.T1_(T0)
        T2 = self.T2_(T1)
        T3 = self.T3_(T2)
        T4 = self.T4_(T3)

        outT = self.ConvLast(T4)
        if self.phase == "train":
            return outL,  outT

# %%
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms
        
    def __call__(self, x):
        for t in self.transforms:
            x = t(x)
        return x
    
class Resize(object):
    def __init__(self, input_size):
        self.input_size = input_size
        
    def __call__(self, img):
        img = img.resize((self.input_size, self.input_size),
                                Image.BICUBIC)
        return img
    
class Normalize_Tensor(object):
    def __init__(self, color_mean, color_std):
        self.color_mean = color_mean
        self.color_std = color_std

    def __call__(self, img):

        # PIL画像をTensorに。大きさは最大1に規格化される
        img = transforms.functional.to_tensor(img)

        # 色情報の標準化
        img = transforms.functional.normalize(
            img, self.color_mean, self.color_std)

        return img

class ImageTransform():
    def __init__(self, input_size, color_mean, color_std):
        self.data_transform = {
            'train' : Compose([
                Resize(input_size),
                Normalize_Tensor(color_mean, color_std)
            ]),
            'val' : Compose([
                Resize(input_size),
                Normalize_Tensor(color_mean, color_std)
            ])
        }
    
    def __call_(self, phase, img):
        return self.data_transform[phase](img)

# %%
############### THIS CELL IS COPIED FROM DEEP SPEECH MOZILLA #########################


from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
import tensorflow.compat.v1 as tfv1
from tensorflow.compat import dimension_value
from tensorflow.contrib.image import dense_image_warp
from tensorflow.contrib.image import interpolate_spline

from tensorflow.python.framework import ops
from tensorflow.python.ops import array_ops

def _to_float32(value):
    return tf.cast(value, tf.float32)

def _to_int32(value):
    return tf.cast(value, tf.int32)

def _get_grid_locations(image_height, image_width):
    """Wrapper for np.meshgrid."""
    tfv1.assert_type(image_height, tf.int32)
    tfv1.assert_type(image_width, tf.int32)

    y_range = tf.range(image_height)
    x_range = tf.range(image_width)
    y_grid, x_grid = tf.meshgrid(y_range, x_range, indexing='ij')
    return tf.stack((y_grid, x_grid), -1)


def _expand_to_minibatch(tensor, batch_size):
    """Tile arbitrarily-sized np_array to include new batch dimension."""
    ndim = tf.size(tf.shape(tensor))
    ones = tf.ones((ndim,), tf.int32)

    tiles = tf.concat(([batch_size], ones), 0)
    return tf.tile(tf.expand_dims(tensor, 0), tiles)


def _get_boundary_locations(image_height, image_width, num_points_per_edge):
    """Compute evenly-spaced indices along edge of image."""
    image_height_end = _to_float32(tf.math.subtract(image_height, 1))
    image_width_end = _to_float32(tf.math.subtract(image_width, 1))
    y_range = tf.linspace(0.0, image_height_end, num_points_per_edge + 2)
    x_range = tf.linspace(0.0, image_height_end, num_points_per_edge + 2)
    ys, xs = tf.meshgrid(y_range, x_range, indexing='ij')
    is_boundary = tf.logical_or(
        tf.logical_or(tf.equal(xs, 0.0), tf.equal(xs, image_width_end)),
        tf.logical_or(tf.equal(ys, 0.0), tf.equal(ys, image_height_end)))
    return tf.stack([tf.boolean_mask(ys, is_boundary), tf.boolean_mask(xs, is_boundary)], axis=-1)


def _add_zero_flow_controls_at_boundary(control_point_locations,
                                        control_point_flows, image_height,
                                        image_width, boundary_points_per_edge):
    """Add control points for zero-flow boundary conditions.
     Augment the set of control points with extra points on the
     boundary of the image that have zero flow.
    Args:
      control_point_locations: input control points
      control_point_flows: their flows
      image_height: image height
      image_width: image width
      boundary_points_per_edge: number of points to add in the middle of each
                             edge (not including the corners).
                             The total number of points added is
                             4 + 4*(boundary_points_per_edge).
    Returns:
      merged_control_point_locations: augmented set of control point locations
      merged_control_point_flows: augmented set of control point flows
    """

    batch_size = dimension_value(tf.shape(control_point_locations)[0])

    boundary_point_locations = _get_boundary_locations(image_height, image_width,
                                                       boundary_points_per_edge)
    boundary_point_shape = tf.shape(boundary_point_locations)
    boundary_point_flows = tf.zeros([boundary_point_shape[0], 2])

    minbatch_locations = _expand_to_minibatch(boundary_point_locations, batch_size)
    type_to_use = control_point_locations.dtype
    boundary_point_locations = tf.cast(minbatch_locations, type_to_use)

    minbatch_flows = _expand_to_minibatch(boundary_point_flows, batch_size)

    boundary_point_flows = tf.cast(minbatch_flows, type_to_use)

    merged_control_point_locations = tf.concat(
        [control_point_locations, boundary_point_locations], 1)

    merged_control_point_flows = tf.concat(
        [control_point_flows, boundary_point_flows], 1)

    return merged_control_point_locations, merged_control_point_flows


def sparse_image_warp(image,
                      source_control_point_locations,
                      dest_control_point_locations,
                      interpolation_order=2,
                      regularization_weight=0.0,
                      num_boundary_points=0,
                      name='sparse_image_warp'):
    """Image warping using correspondences between sparse control points.
    Apply a non-linear warp to the image, where the warp is specified by
    the source and destination locations of a (potentially small) number of
    control points. First, we use a polyharmonic spline
    (`tf.contrib.image.interpolate_spline`) to interpolate the displacements
    between the corresponding control points to a dense flow field.
    Then, we warp the image using this dense flow field
    (`tf.contrib.image.dense_image_warp`).
    Let t index our control points. For regularization_weight=0, we have:
    warped_image[b, dest_control_point_locations[b, t, 0],
                    dest_control_point_locations[b, t, 1], :] =
    image[b, source_control_point_locations[b, t, 0],
             source_control_point_locations[b, t, 1], :].
    For regularization_weight > 0, this condition is met approximately, since
    regularized interpolation trades off smoothness of the interpolant vs.
    reconstruction of the interpolant at the control points.
    See `tf.contrib.image.interpolate_spline` for further documentation of the
    interpolation_order and regularization_weight arguments.
    Args:
      image: `[batch, height, width, channels]` float `Tensor`
      source_control_point_locations: `[batch, num_control_points, 2]` float
        `Tensor`
      dest_control_point_locations: `[batch, num_control_points, 2]` float
        `Tensor`
      interpolation_order: polynomial order used by the spline interpolation
      regularization_weight: weight on smoothness regularizer in interpolation
      num_boundary_points: How many zero-flow boundary points to include at
        each image edge.Usage:
          num_boundary_points=0: don't add zero-flow points
          num_boundary_points=1: 4 corners of the image
          num_boundary_points=2: 4 corners and one in the middle of each edge
            (8 points total)
          num_boundary_points=n: 4 corners and n-1 along each edge
      name: A name for the operation (optional).
      Note that image and offsets can be of type tf.half, tf.float32, or
      tf.float64, and do not necessarily have to be the same type.
    Returns:
      warped_image: `[batch, height, width, channels]` float `Tensor` with same
        type as input image.
      flow_field: `[batch, height, width, 2]` float `Tensor` containing the dense
        flow field produced by the interpolation.
    """

    image = ops.convert_to_tensor(image)
    source_control_point_locations = ops.convert_to_tensor(
        source_control_point_locations)
    dest_control_point_locations = ops.convert_to_tensor(
        dest_control_point_locations)

    control_point_flows = (
        dest_control_point_locations - source_control_point_locations)

    clamp_boundaries = num_boundary_points > 0
    boundary_points_per_edge = num_boundary_points - 1

    with ops.name_scope(name):
        image_shape = tf.shape(image)
        batch_size, image_height, image_width = image_shape[0], image_shape[1], image_shape[2]

        # This generates the dense locations where the interpolant
        # will be evaluated.
        grid_locations = _get_grid_locations(image_height, image_width)

        flattened_grid_locations = tf.reshape(grid_locations,
                                              [tf.multiply(image_height, image_width), 2])

        # flattened_grid_locations = constant_op.constant(
        #     _expand_to_minibatch(flattened_grid_locations, batch_size), image.dtype)
        flattened_grid_locations = _expand_to_minibatch(flattened_grid_locations, batch_size)
        flattened_grid_locations = tf.cast(flattened_grid_locations, dtype=image.dtype)

        if clamp_boundaries:
            (dest_control_point_locations,
             control_point_flows) = _add_zero_flow_controls_at_boundary(
                 dest_control_point_locations, control_point_flows, image_height,
                 image_width, boundary_points_per_edge)

        flattened_flows = interpolate_spline(
            dest_control_point_locations, control_point_flows,
            flattened_grid_locations, interpolation_order, regularization_weight)

        dense_flows = array_ops.reshape(flattened_flows,
                                        [batch_size, image_height, image_width, 2])

        warped_image = dense_image_warp(image, dense_flows)

        return warped_image, dense_flows

# %%
def image_warping(src_img, src_landmarks, dest_landmarks):
    # expanded_src_landmarks = np.expand_dims(np.float32(src_landmarks), axis=0)
    # expanded_dest_landmarks = np.expand_dims(np.float32(dest_landmarks), axis=0)
    # expanded_src_img = np.expand_dims(np.float32(src_img) / 255, axis=0)

    warped_img, dense_flows = sparse_image_warp(src_img,
                          src_landmarks,
                          dest_landmarks,
                          interpolation_order=1,
                          regularization_weight=0.1,
                          num_boundary_points=2,
                          name='sparse_image_warp')

    with tf.Session() as sess:
        out_img = sess.run(warped_img)
        warp_img = np.uint8(out_img[:, :, :, :])
    
    return warp_img
    
def face_landmark(img):
    X = np.zeros((img.shape[0], 72 ,2))
    flag = []
    for i in range(img.shape[0]):

        landmark = face_landmarks(img[i].reshape(224,224,3))
        resultant = []
        try:
            for j in list(landmark[0].keys()):
                resultant += landmark[0][j] 
        except IndexError:
            flag.append(i)
            continue
        X[i] = np.array(resultant)
    return  X, flag

# %%
checkpoint_path='/content/drive/My Drive/Speech2Face/models/face_decoder_warping/new_dataset_v4/epoch_95_steps_0.pth'
#checkpoint_path=None
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Set Model
model = DECODER('train').to(device)
optimizer = optim.Adam(model.parameters())
global_epoch = 0

if checkpoint_path:
    checkpoint = torch.load(checkpoint_path)
    global_epoch = checkpoint["epoch"] +1
    model.load_state_dict(checkpoint["model_state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

# Set loss and optimizer
criterion = nn.MSELoss()
criterion2 = nn.L1Loss()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-c68d61e05e27>", line 10, in <module>
#     checkpoint = torch.load(checkpoint_path)
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 584, in load
#     return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 842, in _load
#     result = unpickler.load()
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 834, in persistent_load
#     load_tensor(data_type, size, key, _maybe_decode_ascii(location))
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 822, in load_tensor
#     storage = zip_file.get_storage_from_record(name, size, dtype).storage()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 738, in getmodule
#     _filesbymodname[modname] = f
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
base_dir='/content/drive/My Drive/Speech2Face/'

# %%
models_list = listdir("/content/drive/My Drive/Speech2Face/models/face_decoder_warping/new_dataset_v4")

# %%
models_list.sort()
print(models_list)

# %%
#import argparse



#from dataloader import EmbedImagePairs
#from face_encoder_model import vgg_face_dag
#from face_decoder_model import Generator


alpha = 0.0002
beta  = 1.0

def _save_model(epoch, model, optimizer, steps, fname):
    torch.save({
        'steps': steps,
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        }, join(output_dir_name, 'epoch_{}_steps_{}.pth'.format(epoch, steps)))


def train_epoch(model, trn_dataloader, criterion, device):
    model.eval()

    running_loss = 0
    dataset_len = len(trn_dataloader.dataset)

    count = 0
    numOfElements = 0
    saving_steps = 50

    # TRAIN
    tqdm_iterator = tqdm(
        enumerate(trn_dataloader),
        total=len(trn_dataloader),
        desc=f"batch [loss: None]",
        leave=False,
    )

    for batch_idx, (x,landmark, y) in tqdm_iterator:
        with torch.no_grad():
          count += 1
          x = x.squeeze().to(device)  
  
          # y_img = cv2.cvtColor(np.einsum('abc->bca',y[0].numpy()*255),cv2.COLOR_BGR2RGB)
          # cv2_imshow(y_img)
  
          y = y.to(device)
          landmark = landmark.to(device)
  
          outLandmark, outputs  = model(x)
  
          loss2 = criterion2(outputs, y)
          loss1 = criterion(outLandmark, landmark)
  
          loss = (alpha*loss1 + beta*loss2 )
          
          
          # o_img = cv2.cvtColor(np.einsum('abc->bca',outputs[0].cpu().detach().numpy()*255),cv2.COLOR_BGR2RGB)
          #cv2_imshow(o_img)
          running_loss += loss.item() * x.size(0)
          numOfElements += x.shape[0]
  
  
          # outLandmark = outLandmark.cpu().detach().numpy()
          # outLandmark = np.dstack((outLandmark[:,0::2],outLandmark[:,1::2]))
          # print("land np img np ", outL_.shape, img_.shape)
          # img1 = np.einsum('dabc->dbca',outputs.cpu().detach().numpy()*255)
          # img1 = (img1).astype(np.uint8)
          #print("img_t ",img_t.shape, img_t[0])
          # src, flag = face_landmark(img1)
          # if flag:
          #     for r in flag:
          #         src[r] = outLandmark[r]
          # result = image_warping(img1.astype(np.float32), src.astype(np.float32), outLandmark.astype(np.float32))
  
          # w_img = cv2.cvtColor(result[0], cv2.COLOR_BGR2RGB)
          #cv2_imshow(w_img)
  
          #print("loss:", running_loss / (x.shape[0] * count) , "Steps:", str(numOfElements) + "/" + str(dataset_len) )
  
          #if (numOfElements % (x.shape[0] * saving_steps)) == 0:
          #  _save_model(epoch, model, optimizer, numOfElements, output_dir_name)
          tqdm_iterator.set_description(
                  f"test batch [running loss: {running_loss:.3f}]"
          )
    
    trn_loss = running_loss/len(trn_dataloader.dataset)
    
    return trn_loss


def train( dataloaders, criterion, device):
    trn_losses = []

    path = "/content/drive/My Drive/Speech2Face/models/face_decoder_warping/new_dataset_v4"
    models_list = listdir(path)

    

    for path_model in models_list:
      checkpoint = torch.load(join(path, path_model))
      model = DECODER('train').to(device)
      model.load_state_dict(checkpoint["model_state_dict"])

      # start at zero, end at num_epochs (including)
      print("Start Training")
      # Training phase
      trn_loss = train_epoch( model, dataloaders, criterion, device)
      trn_losses += [trn_loss]
      print("Loss: {}".format( trn_loss))
      model.cpu()
      del model


    return trn_losses


base_dir='/content/drive/My Drive/Speech2Face/'
input="vox1_dataset/unzippedFaces"
batch_size=32
num_epochs=1

# Load face-encoder model
# face_encoder_path = join(base_dir, "Pretrained", "vgg_face_dag.pth")
# face_encoder_model = vgg_face_dag(face_encoder_path).to(device)
# color_mean, color_std = face_encoder_model.meta["mean"], face_encoder_model.meta["std"]
# color_mean = [tmp / 255.0 for tmp in color_mean]
# color_std = [tmp / 255.0 for tmp in color_std]

# Set DataLoader
input_path = '/content/Face_Feature/'
print('Image Pairing')
dataset = EmbedImagePairs(input_path)
print('Creating dataloader')
trn_dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=8)
output_dir_name = join(base_dir, "models", "face_decoder_warping/new_dataset_v4")
# Out:
# Image Pairing
# Creating dataloader

# %%
# del model
# Train
criterion = nn.MSELoss()
criterion2 = nn.L1Loss()
device='cuda'
loss = train( trn_dataloader, criterion, device)
print("Finish training")
# Out:
# Start Training
# Loss: 0.5456818866729737
# Start Training
# Loss: 0.548774220943451
# Start Training
# Loss: 0.542171196937561
# Start Training
# Loss: 0.5063612159093221
# Start Training
# Loss: 0.4990966097513835
# Start Training
# Loss: 0.5009104617436727
# Start Training
# Loss: 0.47767128149668375
# Start Training
# Loss: 0.48187875747680664
# Start Training
# Loss: 0.48203266541163126
# Start Training
# Loss: 0.48308666865030925
# Start Training
# Loss: 0.4804776334762573
# Start Training
# Loss: 0.4774358467260997
# Start Training
# Loss: 0.4775967001914978
# Start Training
# Loss: 0.47628641764322915
# Start Training
# Loss: 0.47746851126352946
# Start Training
# Loss: 0.4766764728228251
# Start Training
# Loss: 0.4776858290036519
# Start Training
# Loss: 0.46595731894175213
# Start Training
# Loss: 0.46362706462542214
# Start Training
# Loss: 0.4614138917128245
# Start Training
# Loss: 0.46176956335703534
# Start Training
# Loss: 0.4609352318445841
# Start Training
# Loss: 0.46323339263598123
# Start Training
# Loss: 0.46026979128519696
# Start Training
# Loss: 0.4563087276617686
# Start Training
# Loss: 0.4590461583932241
# Start Training
# Loss: 0.4574252239863078
# Start Training
# Loss: 0.4592110013961792
# Start Training
# Loss: 0.4601018444697062
# Start Training
# Loss: 0.4560572544733683
# Start Training
# Loss: 0.45729748010635374
# Start Training
# Loss: 0.4574363895257314
# Start Training
# Loss: 0.45596044103304545
# Start Training
# Loss: 0.4566684822241465
# Start Training
# Loss: 0.4558779803911845
# Start Training
# Loss: 0.45922678550084434
# Start Training
# Loss: 0.4526396044095357
# Start Training
# Loss: 0.4367535738150279
# Start Training
# Loss: 0.4374035143852234
# Start Training
# Loss: 0.43583271821339925
# Start Training
# Loss: 0.43589943170547485
# Start Training
# Loss: 0.43330782930056255

# %%
import matplotlib.pyplot as plt

plt.plot(loss)
plt.show()

# %%
base_dir='/content/drive/My Drive/Speech2Face/'
face_encoder_path = join(base_dir, "Pretrained", "vgg_face_dag.pth")
face_encoder_model = vgg_face_dag(face_encoder_path)
face_encoder_model.eval()
face_encoder_model.to(device)

color_mean, color_std = face_encoder_model.meta["mean"], face_encoder_model.meta["std"]
color_mean = [tmp / 255.0 for tmp in color_mean]
color_std = [tmp / 255.0 for tmp in color_std]
model.eval()
img = Image.open('/content/338x338-10-graziano-frontal.png')
# img = Image.open('/content/1966c850f1620718bc846793a0a0d78f.jpg')
transform_fe = transforms.Compose([
            transforms.Resize((224, 224)),
            _Normalize_Tensor(color_mean, color_std)
        ])


t_img = transform_fe(img).unsqueeze(0).to(device)
emb = face_encoder_model(t_img)
land_out, outputs  = model(emb)
display(img)

# %%
o_img = cv2.cvtColor(np.einsum('abc->bca',outputs[0].cpu().detach().numpy()*255),cv2.COLOR_BGR2RGB)
cv2_imshow(o_img)

outLandmark = land_out.cpu().detach().numpy()
# outLandmark = np.dstack((outLandmark[:,0::2],outLandmark[:,1::2]))
print(img.size)
print(t_img.shape)

outLandmark = outLandmark.reshape((-1, 72, 2))
outLandmark = np.interp(outLandmark, (outLandmark.min(), outLandmark.max()), (0, 224))


# print("land np img np ", outL_.shape, img_.shape)
img1 = np.einsum('dabc->dbca',outputs.cpu().detach().numpy()*255)
img1 = (img1).astype(np.uint8)
# print("img_t ",img_t.shape, img_t[0])
src, flag = face_landmark(img1)
if flag:
    for r in flag:
        src[r] = outLandmark[r] 

diff = np.median(outLandmark, axis=1) - np.median(src, axis=1)

right_list = set()
for i in range(outLandmark.shape[1]):
  if not (outLandmark[0,i,0] == 0 or outLandmark[0,i,1] == 0) :
    right_list.add(i)

good_list = np.array(list(right_list))
src_new = src[:,good_list]
outLandmark_new = outLandmark[:,good_list]
outLandmark_new[:,:] -= diff
result = image_warping(img1.astype(np.float32), src_new.astype(np.float32), outLandmark_new.astype(np.float32))
w_img = cv2.cvtColor(result[0], cv2.COLOR_BGR2RGB)
cv2_imshow(w_img)

# %%
import matplotlib.pyplot as plt

def plotLandmarks(img, landmarks):
  img_p = img.squeeze(0)
  fig = plt.figure(figsize=(15, 5))
  ax = fig.add_subplot(1, 3, 1)
  ax.imshow(img_p)
  ax = fig.add_subplot(1, 3, 2)
  ax.scatter(landmarks[:,0], -landmarks[:,1], alpha=0.8)
  ax = fig.add_subplot(1, 3, 3)
  img2 = img_p.copy()

  for p in landmarks[:].astype(np.uint8):
      img2[p[1]-2:p[1]+2, p[0]-2:p[0]+2, :] = (255, 255, 255)
      # note that the values -3 and +3 will make the landmarks
      # overlayed on the image 6 pixels wide; depending on the
      # resolution of the face image, you may want to change
      # this value


  ax.imshow(img2)
  plt.show()

plotLandmarks(img1, src.squeeze())

# %%
plotLandmarks(img1, outLandmark_new[0])
